# %% [markdown]
# # Esfandiar Kiani (40311614) - ML Homework 02.5

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# ## Load data

# %%
FILE_PATH = "D:/M.A/T1/ML/Assignments/HW2_Regression_code  datasets/abalone.csv"
abalone = fetch_ucirepo(id=1)

# %%
# df = pd.read_csv(FILE_PATH)

# %%
x = abalone.data.features
y = abalone.data.targets

# %% [markdown]
# ## Meta data

# %%
print(x.head())
print()
print('_______________________________________________')
print()
print(y.head())
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight
# 0         0.150
# 1         0.070
# 2         0.210
# 3         0.155
# 4         0.055
#
# _______________________________________________
#
#    Rings
# 0     15
# 1      7
# 2      9
# 3     10
# 4      7

# %%
print(x.info())
print()
print('_______________________________________________')
print()
print(y.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 261.2+ KB
# None
#
# _______________________________________________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rings   4177 non-null   int64
# dtypes: int64(1)
# memory usage: 32.8 KB
# None

# %%
print(x.describe())
print()
print('_______________________________________________')
print()
print(y.describe())
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight
# count     4177.000000   4177.000000
# mean         0.180594      0.238831
# std          0.109614      0.139203
# min          0.000500      0.001500
# 25%          0.093500      0.130000
# 50%          0.171000      0.234000
# ...

# %% [markdown]
# ## MSE

# %%
def MSE(y_true, y_pred):
    return sum((true - pred) ** 2 for true, pred in zip(y_true, y_pred)) / len(y_true)

# %% [markdown]
# ## Data cleansing

# %%
x = x.drop(columns=['Sex'])
print(x.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Length          4177 non-null   float64
#  1   Diameter        4177 non-null   float64
#  2   Height          4177 non-null   float64
#  3   Whole_weight    4177 non-null   float64
#  4   Shucked_weight  4177 non-null   float64
#  5   Viscera_weight  4177 non-null   float64
#  6   Shell_weight    4177 non-null   float64
# dtypes: float64(7)
# memory usage: 228.6 KB
# None

# %% [markdown]
# ## Train/Test split

# %%
ratio = 0.8

# %%
x_train, x_test = x[:int(ratio*len(x))], x[int(ratio*len(x)):]
y_train, y_test = y[:int(ratio*len(y))], y[int(ratio*len(y)):]

# %%
print(x_train.info(), x_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3341 entries, 0 to 3340
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Length          3341 non-null   float64
#  1   Diameter        3341 non-null   float64
#  2   Height          3341 non-null   float64
#  3   Whole_weight    3341 non-null   float64
#  4   Shucked_weight  3341 non-null   float64
#  5   Viscera_weight  3341 non-null   float64
#  6   Shell_weight    3341 non-null   float64
# dtypes: float64(7)
# memory usage: 182.8 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 3341 to 4176
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Length          836 non-null    float64
#  1   Diameter        836 non-null    float64
#  2   Height          836 non-null    float64
#  3   Whole_weight    836 non-null    float64
# ...

# %% [markdown]
# ## Models

# %% [markdown]
# ### a) Linear

# %%
class LinearRegression:
    def fit(self, X, y):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]
        self.theta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

    def predict(self, X):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]
        return X_b @ self.theta

# %% [markdown]
# ### b&c) Polynomial

# %%
class PolynomialRegression:
    def __init__(self, degree):
        self.degree = degree

    def fit(self, X, y):
        self.X_poly = self._polynomial_features(X)
        # self.theta = np.linalg.inv(self.X_poly.T @ self.X_poly) @ self.X_poly.T @ y
        #! Convert inv to pinv due to singular matrix error
        self.theta = np.linalg.pinv(self.X_poly.T @ self.X_poly) @ self.X_poly.T @ y

    def predict(self, X):
        X_poly = self._polynomial_features(X)
        return X_poly @ self.theta

    def _polynomial_features(self, X):
        return np.hstack([X ** i for i in range(self.degree + 1)])

# %% [markdown]
# ### d) RBF kernel functions

# %%
class RBFKernelRegression:
    def __init__(self, gamma):
        self.gamma = gamma

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        K = np.exp(-self.gamma * self._squared_distances(X, self.X_train))
        return K @ self.y_train / np.sum(K, axis=1)

    def _squared_distances(self, X1, X2):
        return np.sum(X1**2, axis=1).reshape(-1, 1) + np.sum(X2**2, axis=1) - 2 * X1 @ X2.T

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Polynomial Regression (degree=2)': PolynomialRegression(degree=2),
    'Polynomial Regression (degree=3)': PolynomialRegression(degree=3),
    'RBF Kernel Regression': RBFKernelRegression(gamma=0.1)
}

# %% [markdown]
# ## Fit, predict, and evaluation

# %%
for name, model in models.items():
    
    model.fit(x_train.values, y_train.values)
    
    y_train_pred = model.predict(x_train.values)
    y_test_pred = model.predict(x_test.values)
    
    train_mse = MSE(y_train.values, y_train_pred)
    test_mse = MSE(y_test.values, y_test_pred)
    
    print(f"{name}: Train MSE = {train_mse}, Test MSE = {test_mse}")
# Out:
# Linear Regression: Train MSE = [5.13122559], Test MSE = [4.08439582]
# Polynomial Regression (degree=2): Train MSE = [4.75950206], Test MSE = [3.59477668]
# Polynomial Regression (degree=3): Train MSE = [4.72903191], Test MSE = [3.578687]
# RBF Kernel Regression: Train MSE = [10.94692703 10.93164895 10.99093943 ... 11.33351669 10.99976237
#  10.98960104], Test MSE = [ 7.05718336  7.23644348  7.18156294  7.08887841  7.0533586   7.09883249
#   7.29332508  7.03204262  7.11489657  7.16813914  7.05660923  7.02153427
#   7.12015673  7.12948057  7.16533462  7.28894212  7.41409378  7.86260545
#   7.09969138  7.06321672  7.2904271   7.29821515  7.02472316  7.61515108
#   7.21467001  7.92885599  7.07398078  7.07930133  7.18057386  7.1359016
#   7.64064494  7.09588923  7.03373274  7.05643994  7.08430992  7.75833349
#   8.00583937  7.62761572  7.87761103  8.41179331  7.04438024  7.03676433
#   7.02639742  7.70752483  7.10315667  7.0324817   7.02621866  8.34625618
# ...

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, glob
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils import shuffle

# %% [markdown]
# ## Hyperparameters

# %%
INPUT_DIM = 6
HIDDEN_DIM1 = 64
HIDDEN_DIM2 = 32
# OUTPUT_DIM = 10
TIMESTEPS = 50
TRAIN_RATIO = 0.8
EPOCHS = 500
LEARNING_RATE = 0.00001
MAX_GRAD_NORM = 1.0
SEED = 13
DATA_PATH = "./Dataset/"
STATEFUL = False

# %%
np.random.seed(SEED)

# %% [markdown]
# ## Load Dataset

# %%
# file_paths = sorted(glob.glob(os.path.join(DATA_PATH, "*.csv")))
file_paths = "./Dataset/har70+_505.csv"

# %%
df = pd.read_csv(file_paths)
har_data = df

# %%
# all_data = []
# for file in file_paths:
#     df = pd.read_csv(file)
#     df['source_file'] = os.path.basename(file)
#     all_data.append(df)

# har_data = pd.concat(all_data, ignore_index=True)

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(12, 5))
plt.plot(har_data['back_x'][:500], label="back_x")
plt.plot(har_data['thigh_x'][:500], label="thigh_x")
plt.title("Sensor Readings Sample")
plt.xlabel("Timestep")
plt.ylabel("Sensor Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
har_data['label'].value_counts().sort_index().plot(kind='bar')
plt.title("Class Distribution")
plt.xlabel("Class Label")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
features = ['back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y', 'thigh_z']
X_raw = har_data[features].values
y_raw = har_data['label'].values

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_raw)

# %%
def create_lstm_sequences(X, y, timesteps=50):
    X_seq, y_seq = [], []
    for i in range(len(X) - timesteps):
        X_seq.append(X[i:i+timesteps])
        y_seq.append(y[i+timesteps-1])
    return np.array(X_seq), np.array(y_seq)

# %%
X_seq, y_seq = create_lstm_sequences(X_scaled, y_raw, TIMESTEPS)

# %%
unique_labels = np.unique(y_seq)
print("Original labels before mapping:", unique_labels)

label_map = {old: new for new, old in enumerate(unique_labels)}
print("\nLabel mapping:")
for original, new in label_map.items():
    print(f"  Original Label {original} → Mapped Label {new}")

print("\nClass Distribution before Mapping:")
unique, counts = np.unique(y_seq, return_counts=True)
for cls, count in zip(unique, counts):
    print(f"  Class {cls}: {count} samples")

print("\ny_seq range:", y_seq.min(), "to", y_seq.max())
# Out:
# Original labels before mapping: [1 3 6 7 8]
#
# Label mapping:
#   Original Label 1 → Mapped Label 0
#   Original Label 3 → Mapped Label 1
#   Original Label 6 → Mapped Label 2
#   Original Label 7 → Mapped Label 3
#   Original Label 8 → Mapped Label 4
#
# Class Distribution before Mapping:
#   Class 1: 24313 samples
#   Class 3: 1768 samples
#   Class 6: 17269 samples
#   Class 7: 30226 samples
#   Class 8: 13380 samples
#
# y_seq range: 1 to 8

# %%
# unique_labels = np.unique(y_seq)
# print(unique_labels)
# label_map = {old: new for new, old in enumerate(unique_labels)}

# %%
y_seq_mapped = np.array([label_map[y] for y in y_seq])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq_mapped, test_size=1-TRAIN_RATIO, random_state=SEED, stratify=y_seq_mapped)

# %%
np.unique(y_train), y_train.min(), y_train.max()
# Out:
# (array([0, 1, 2, 3, 4]), 0, 4)

# %%
OUTPUT_DIM = len(unique_labels)

# %%
print(OUTPUT_DIM)
# Out:
# 5

# %%
print("Class Distribution After Mapping:")
unique, counts = np.unique(y_train, return_counts=True)
for cls, count in zip(unique, counts):
    print(f"Class {cls}: {count} samples")

print("\ny_train range:", y_train.min(), "to", y_train.max())
print("OUTPUT_DIM:", OUTPUT_DIM)
# Out:
# Class Distribution After Mapping:
# Class 0: 19450 samples
# Class 1: 1414 samples
# Class 2: 13815 samples
# Class 3: 24181 samples
# Class 4: 10704 samples
#
# y_train range: 0 to 4
# OUTPUT_DIM: 5

# %% [markdown]
# ## Data Rebalancing

# %%
X_reshaped = X_seq.reshape(len(X_seq), -1)
rus = RandomUnderSampler(random_state=SEED)
X_balanced, y_balanced = rus.fit_resample(X_reshaped, y_seq_mapped)
X_balanced = X_balanced.reshape(-1, TIMESTEPS, INPUT_DIM)
X_balanced, y_balanced = shuffle(X_balanced, y_balanced, random_state=SEED)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, test_size=1 - TRAIN_RATIO, random_state=SEED, stratify=y_balanced
)

# %%
_, counts = np.unique(y_train, return_counts=True)
total = np.sum(counts)
class_weights = total / (counts * len(counts))

# %% [markdown]
# ## Create Sequence

# %%
def create_lstm_sequences(X, y, timesteps=50):
    X_seq, y_seq = [], []
    for i in range(len(X) - timesteps):
        X_seq.append(X[i:i+timesteps])
        y_seq.append(y[i+timesteps-1])
    return np.array(X_seq), np.array(y_seq)

# %% [markdown]
# ## Batch Norm

# %%
class BatchNorm:
    def __init__(self, dim, eps=1e-5):
        self.gamma = np.ones((dim, 1))
        self.beta = np.zeros((dim, 1))
        self.eps = eps

    def forward(self, x):
        self.mu = np.mean(x, keepdims=True)
        self.var = np.var(x, keepdims=True)
        self.x_norm = (x - self.mu) / np.sqrt(self.var + self.eps)
        return self.gamma * self.x_norm + self.beta

    def backward(self, dout):
        N = dout.shape[0]
        x_mu = self.x_norm
        std_inv = 1. / np.sqrt(self.var + self.eps)

        dx_norm = dout * self.gamma
        dvar = np.sum(dx_norm * (x_mu * -0.5) * std_inv**3, axis=0)
        dmu = np.sum(dx_norm * -std_inv, axis=0) + dvar * np.mean(-2. * x_mu, axis=0)
        dx = dx_norm * std_inv + dvar * 2 * x_mu / N + dmu / N

        self.dgamma = np.sum(dout * x_mu, axis=0, keepdims=True).T
        self.dbeta = np.sum(dout, axis=0, keepdims=True).T
        return dx

    def apply_grads(self, lr):
        self.gamma -= lr * self.dgamma
        self.beta -= lr * self.dbeta

# %% [markdown]
# ## Functions

# %%
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / np.sum(e_x)

# %%
def sigmoid(self, x):
    x = np.clip(x, -500, 500)
    return 1 / (1 + np.exp(-x))

# %%
def cross_entropy(pred, label, num_classes):
    y_onehot = np.zeros((num_classes, 1))
    y_onehot[label] = 1
    return -np.sum(y_onehot * np.log(pred + 1e-8))

# %%
def cross_entropy(pred, label, num_classes, class_weights=None):
    y_onehot = np.zeros((num_classes, 1))
    y_onehot[label] = 1
    weight = class_weights[label] if class_weights is not None else 1.0
    return -weight * np.sum(y_onehot * np.log(pred + 1e-8))

# %%
def d_cross_entropy(pred, label, num_classes):
    y_onehot = np.zeros((num_classes, 1))
    y_onehot[label] = 1
    return pred - y_onehot

# %%
def d_cross_entropy(pred, label, num_classes, class_weights=None):
    y_onehot = np.zeros((num_classes, 1))
    y_onehot[label] = 1
    weight = class_weights[label] if class_weights is not None else 1.0
    return weight * (pred - y_onehot)

# %%
def clip_gradients(gradients, max_norm=1.0):
    total_norm = np.sqrt(sum(np.sum(g**2) for g in gradients))
    if total_norm > max_norm:
        scale = max_norm / (total_norm + 1e-6)
        return [g * scale for g in gradients]
    return gradients

# %% [markdown]
# ## Model

# %% [markdown]
# ### Base GRU

# %%
class GRUCell:
    def __init__(self, input_dim, hidden_dim):
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim

        def init(): return np.random.randn(hidden_dim, input_dim + hidden_dim) / np.sqrt(input_dim + hidden_dim)

        self.Wz, self.bz = init(), np.zeros((hidden_dim, 1))
        self.Wr, self.br = init(), np.zeros((hidden_dim, 1))
        self.Wh, self.bh = init(), np.zeros((hidden_dim, 1))

    def zero_grads(self):
        self.dWz = np.zeros_like(self.Wz)
        self.dbz = np.zeros_like(self.bz)
        self.dWr = np.zeros_like(self.Wr)
        self.dbr = np.zeros_like(self.br)
        self.dWh = np.zeros_like(self.Wh)
        self.dbh = np.zeros_like(self.bh)

    def sigmoid(self, x):
        x = np.clip(x, -500, 500)
        return 1 / (1 + np.exp(-x))

    def forward(self, x_seq):
        self.cache = []
        h = np.zeros((self.hidden_dim, 1))
        self.h_seq = []

        for xt in x_seq:
            xt = xt.reshape(-1, 1)
            concat = np.vstack((h, xt))
            z = self.sigmoid(self.Wz @ concat + self.bz)
            r = self.sigmoid(self.Wr @ concat + self.br)

            concat_r = np.vstack((r * h, xt))
            h_tilde = np.tanh(self.Wh @ concat_r + self.bh)
            h = (1 - z) * h + z * h_tilde

            self.cache.append({
                'xt': xt, 'h_prev': h.copy(), 'z': z, 'r': r, 'h_tilde': h_tilde, 'concat': concat, 'concat_r': concat_r
            })
            self.h_seq.append(h.copy())

        return self.h_seq

    def backward(self, dh_last):
        dh_next = dh_last
        self.reset_grads()

        for t in reversed(range(len(self.cache))):
            cache = self.cache[t]
            xt, h_prev, z, r, h_tilde = cache['xt'], cache['h_prev'], cache['z'], cache['r'], cache['h_tilde']
            concat, concat_r = cache['concat'], cache['concat_r']

            dh = dh_next
            dz = (h_tilde - h_prev) * dh
            dh_tilde = z * dh
            dh_prev_part = (1 - z) * dh

            dz_raw = dz * z * (1 - z)
            dr = ((self.Wh[:, :self.hidden_dim].T @ (1 - h_tilde**2) * dh_tilde) * h_prev) * r * (1 - r)
            dh_tilde_raw = (1 - h_tilde**2) * dh_tilde

            self.dWz += dz_raw @ concat.T
            self.dbz += dz_raw
            self.dWr += dr @ concat.T
            self.dbr += dr
            self.dWh += dh_tilde_raw @ concat_r.T
            self.dbh += dh_tilde_raw

            d_concat = (self.Wz.T @ dz_raw) + (self.Wr.T @ dr)
            d_concat += self.Wh.T @ dh_tilde_raw

            dh_next = d_concat[:self.hidden_dim, :] + dh_prev_part

    def apply_grads(self, lr):
        for param, grad in zip(
            [self.Wz, self.bz, self.Wr, self.br, self.Wh, self.bh],
            [self.dWz, self.dbz, self.dWr, self.dbr, self.dWh, self.dbh]
        ):
            param -= lr * grad

# %% [markdown]
# ### Stacked GRU

# %%
class StackedGRUClassifier:
    def __init__(self, input_dim, hidden1, hidden2, output_dim, stateful=False):
        self.stateful = stateful 

        self.gru1 = GRUCell(input_dim, hidden1)
        self.gru2 = GRUCell(hidden1, hidden2)

        self.W_out = np.random.randn(output_dim, hidden2) / np.sqrt(hidden2)
        self.b_out = np.zeros((output_dim, 1))

        self.h1 = None
        self.h2 = None

    def reset_states(self):
        self.h1 = None
        self.h2 = None

    def forward(self, x_seq):
        h1_seq = []
        h = self.h1 if (self.stateful and self.h1 is not None) else np.zeros((self.gru1.hidden_dim, 1))
        self.gru1.cache = []

        for xt in x_seq:
            xt = xt.reshape(-1, 1)
            concat = np.vstack((h, xt))
            z = self.sigmoid(self.gru1.Wz @ concat + self.gru1.bz)
            r = self.sigmoid(self.gru1.Wr @ concat + self.gru1.br)
            concat_r = np.vstack((r * h, xt))
            h_tilde = np.tanh(self.gru1.Wh @ concat_r + self.gru1.bh)
            h = (1 - z) * h + z * h_tilde
            self.gru1.cache.append({'xt': xt, 'h': h.copy(), 'z': z, 'r': r, 'h_tilde': h_tilde, 'concat': concat, 'concat_r': concat_r})
            h1_seq.append(h.copy())

        if self.stateful:
            self.h1 = h.copy()

        h2_seq = []
        h = self.h2 if (self.stateful and self.h2 is not None) else np.zeros((self.gru2.hidden_dim, 1))
        self.gru2.cache = []

        for h1 in h1_seq:
            xt = h1
            concat = np.vstack((h, xt))
            z = self.sigmoid(self.gru2.Wz @ concat + self.gru2.bz)
            r = self.sigmoid(self.gru2.Wr @ concat + self.gru2.br)
            concat_r = np.vstack((r * h, xt))
            h_tilde = np.tanh(self.gru2.Wh @ concat_r + self.gru2.bh)
            h = (1 - z) * h + z * h_tilde
            self.gru2.cache.append({'xt': xt, 'h': h.copy(), 'z': z, 'r': r, 'h_tilde': h_tilde, 'concat': concat, 'concat_r': concat_r})
            h2_seq.append(h.copy())

        if self.stateful:
            self.h2 = h.copy()

        self.h2_seq = h2_seq
        self.h2 = h2_seq[-1]
        logits = self.W_out @ self.h2 + self.b_out
        self.probs = self.softmax(logits)
        return self.probs.flatten()

    def softmax(self, x):
        e_x = np.exp(x - np.max(x))
        return e_x / np.sum(e_x)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def backward(self, d_output):
        d_output = d_output.reshape(-1, 1)
        self.dW_out = d_output @ self.h2.T
        self.db_out = d_output
    
        # Backprop to GRU2
        dh_next = self.W_out.T @ d_output
        self.gru2.zero_grads()
        dh_gru1 = []
    
        for t in reversed(range(len(self.gru2.cache))):
            cache = self.gru2.cache[t]
            z, r, h_tilde = cache['z'], cache['r'], cache['h_tilde']
            h_prev = self.gru2.cache[t-1]['h'] if t > 0 else np.zeros_like(dh_next)
    
            dh = dh_next
            dh_tilde = dh * z * (1 - h_tilde ** 2)
            dz = dh * (h_tilde - h_prev) * z * (1 - z)
        
            self.gru2.dWh += dh_tilde @ cache['concat_r'].T
            self.gru2.dbh += dh_tilde
            self.gru2.dWz += dz @ cache['concat'].T
            self.gru2.dbz += dz
        
            # استخراج dxt (خروجی GRU1)
            d_concat = self.gru2.Wh.T @ dh_tilde + self.gru2.Wz.T @ dz
            dh = d_concat[:self.gru2.hidden_dim, :]
            dxt = d_concat[self.gru2.hidden_dim:, :]  # ← مهم‌ترین اصلاح
        
            dh_gru1.append(dxt)
            dh_next = dh
    
        # برعکس کردن لیست برای تطابق با forward GRU1
        dh_gru1 = dh_gru1[::-1]
    
        # Backprop to GRU1
        self.gru1.zero_grads()
        for t in reversed(range(len(self.gru1.cache))):
            cache = self.gru1.cache[t]
            z, r, h_tilde = cache['z'], cache['r'], cache['h_tilde']
            h_prev = self.gru1.cache[t-1]['h'] if t > 0 else np.zeros_like(dh_gru1[t])
    
            dh = dh_gru1[t]
            dh_tilde = dh * z * (1 - h_tilde ** 2)
            dz = dh * (h_tilde - h_prev) * z * (1 - z)
    
            self.gru1.dWh += dh_tilde @ cache['concat_r'].T
            self.gru1.dbh += dh_tilde
            self.gru1.dWz += dz @ cache['concat'].T
            self.gru1.dbz += dz


    def apply_grads(self, lr):
        self.W_out -= lr * self.dW_out
        self.b_out -= lr * self.db_out
        self.gru1.apply_grads(lr)
        self.gru2.apply_grads(lr)

# %%
# del model, train_losses, train_accuracies, test_losses, test_accuracies

# %% [markdown]
# ## Main

# %% [markdown]
# ### Train

# %%
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

# %%
model = StackedGRUClassifier(INPUT_DIM, HIDDEN_DIM1, HIDDEN_DIM2, OUTPUT_DIM, stateful=STATEFUL)

# %%
for epoch in range(EPOCHS):
    loss = 0
    correct = 0
    total = 0
    
    for i in range(1000):    
        probs = model.forward(X_train[i])
        
        loss += cross_entropy(probs, y_train[i], OUTPUT_DIM, class_weights)
        d_out = d_cross_entropy(probs.reshape(-1, 1), y_train[i], OUTPUT_DIM, class_weights)

        model.backward(d_out)

        model.apply_grads(LEARNING_RATE)

        pred_label = np.argmax(probs)
        true_label = y_train[i]
        if pred_label == true_label:
            correct += 1
        total += 1

    avg_loss = loss / total
    accuracy = correct / total

    print(f"Epoch {epoch+1}\nTrain Loss: {avg_loss:.4f}, Train Accuracy: {accuracy:.4f}")
    train_losses.append(avg_loss)
    train_accuracies.append(accuracy)

    test_loss = 0
    test_correct = 0
    test_total = len(X_test)

    for i in range(test_total):
        probs_test = model.forward(X_test[i])
        test_loss += cross_entropy(probs_test, y_test[i], OUTPUT_DIM, class_weights)
        pred_label_test = np.argmax(probs_test)
        if pred_label_test == y_test[i]:
            test_correct += 1

    test_avg_loss = test_loss / test_total
    test_accuracy = test_correct / test_total

    print(f"Test Loss: {test_avg_loss:.4f}, Test Accuracy: {test_accuracy:.4f}\n")
    test_losses.append(test_avg_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epo
#
# Epoch 75
# Train Loss: 14.0298, Train Accuracy: 0.7150
# Test Loss: 14.0463, Test Accuracy: 0.7019
#
# Epoch 76
# Train Loss: 14.0368, Train Accuracy: 0.7160
# Test Loss: 14.0533, Test Accuracy: 0.7019
#
# Epoch 77
# Train Loss: 14.0438, Train Accuracy: 0.7160
# Test Loss: 14.0603, Test Accuracy: 0.7019
#
# Epoch 78
# Train Loss: 14.0508, Train Accuracy: 0.7160
# Test Loss: 14.0672, Test Accuracy: 0.7019
#
# Epoch 79
# Train Loss: 14.0577, Train Accuracy: 0.7170
# Test Loss: 14.0742, Test Accuracy: 0.7019
#
# Epoch 80
# Train Loss: 14.0647, Train Accuracy: 0.7170
# Test Loss: 14.0812, Test Accuracy: 0.7019
#
# Epoch 81
# Train Loss: 14.0717, Train Accuracy: 0.7170
# Test Loss: 14.0881, Test Accuracy: 0.7014
#
# Epoch 82
# Train Loss: 14.0786, Train Accuracy: 0.7150
# Test Loss: 14.0950, Test Accuracy: 0.7019
#
# Epoch 83
# Train Loss: 14.0855, Train Accuracy: 0.7140
# Test Loss: 14.1020, Test Accuracy: 0.7025
#
# Epoch 84
# Train Loss: 14.0925, Train Accuracy: 0.7140
# Test Loss: 14.1089, Test Accuracy: 0.7031
#
# Epoch 85
# Train Loss: 14.0994, Train Accuracy: 0.7130
# Test Loss: 14.1158, Test Accuracy: 0.7031
#
# Epoch 86
# Train Loss: 14.1063, Train Accuracy: 0.7130
# Test Loss: 14.1227, Test Accuracy: 0.7031
#
# Epoch 87
# Train Loss: 14.1131, Train Accuracy: 0.7130
# Test Loss: 14.1295, Test Accuracy: 0.7036
#
# Epoch 88
# Train Loss: 14.1200, Train Accuracy: 0.7130
# Test Loss: 14.1364, Test Accuracy: 0.7031
#
# Epoch 89
# Train Loss: 14.1269, Train Accuracy: 0.7130
# Test Loss: 14.1433, Test Accuracy: 0.7036
#
# Epoch 90
# Train Loss: 14.1337, Train Accuracy: 0.7130
# Test Loss: 14.1501, Test Accuracy: 0.7042
#
# Epoch 91
# Train Loss: 14.1406, Train Accuracy: 0.7130
# Test Loss: 14.1569, Test Accuracy: 0.7042
#
# Epoch 92
# Train Loss: 14.1474, Train Accuracy: 0.7130
# Test Loss: 14.1638, Test Accuracy: 0.7042
#
# Epoch 93
# Train Loss: 14.1542, Train Accuracy: 0.7130
# Test Loss: 14.1706, Test Accuracy: 0.7031
#
# Epoch 94
# Train Loss: 14.1610, Train Accuracy: 0.7130
# Test Loss: 14.1774, Test Accuracy: 0.7031
#
# Epoch 95
# Train Loss: 14.1678, Train Accuracy: 0.7130
# Test Loss: 14.1842, Test Accuracy: 0.7031
#
# Epoch 96
# Train Loss: 14.1746, Train Accuracy: 0.7110
# Test Loss: 14.1909, Test Accuracy: 0.7036
#
# Epoch 97
# Train Loss: 14.1814, Train Accuracy: 0.7110
# Test Loss: 14.1977, Test Accuracy: 0.7031
#
# Epoch 98
# Train Loss: 14.1882, Train Accuracy: 0.7110
# Test Loss: 15.3210, Test Accuracy: 0.7206
#
# Epoch 289
# Train Loss: 15.3113, Train Accuracy: 0.7200
# Test Loss: 15.3261, Test Accuracy: 0.7200
#
# Epoch 290
# Train Loss: 15.3164, Train Accuracy: 0.7200
# Test Loss: 15.3312, Test Accuracy: 0.7195
#
# Epoch 291
# Train Loss: 15.3215, Train Accuracy: 0.7200
# Test Loss: 15.3363, Test Accuracy: 0.7195
#
# Epoch 292
# Train Loss: 15.3267, Train Accuracy: 0.7200
# Test Loss: 15.3414, Test Accuracy: 0.7195
#
# Epoch 293
# Train Loss: 15.3318, Train Accuracy: 0.7200
# Test Loss: 15.3465, Test Accuracy: 0.7195
#
# Epoch 294
# Train Loss: 15.3369, Train Accuracy: 0.7200
# Test Loss: 15.3516, Test Accuracy: 0.7189
#
# Epoch 295
# Train Loss: 15.3419, Train Accuracy: 0.7200
# Test Loss: 15.3567, Test Accuracy: 0.7189
#
# Epoch 296
# Train Loss: 15.3470, Train Accuracy: 0.7200
# Test Loss: 15.3618, Test Accuracy: 0.7189
#
# Epoch 297
# Train Loss: 15.3521, Train Accuracy: 0.7200
# Test Loss: 15.3668, Test Accuracy: 0.7189
#
# Epoch 298
# Train Loss: 15.3572, Train Accuracy: 0.7200
# Test Loss: 15.3719, Test Accuracy: 0.7189
#
# Epoch 299
# Train Loss: 15.3622, Train Accuracy: 0.7200
# Test Loss: 15.3769, Test Accuracy: 0.7189
#
# Epoch 300
# Train Loss: 15.3673, Train Accuracy: 0.7200
# Test Loss: 15.3820, Test Accuracy: 0.7189
#
# Epoch 301
# Train Loss: 15.3723, Train Accuracy: 0.7200
# Test Loss: 15.3870, Test Accuracy: 0.7183
#
# Epoch 302
# Train Loss: 15.3774, Train Accuracy: 0.7200
# Test Loss: 15.3921, Test Accuracy: 0.7183
#
# Epoch 303
# Train Loss: 15.3824, Train Accuracy: 0.7200
# Test Loss: 15.3971, Test Accuracy: 0.7183
#
# Epoch 304
# Train Loss: 15.3875, Train Accuracy: 0.7200
# Test Loss: 15.4021, Test Accuracy: 0.7183
#
# Epoch 305
# Train Loss: 15.3925, Train Accuracy: 0.7200
# Test Loss: 15.4072, Test Accuracy: 0.7183
#
# Epoch 306
# Train Loss: 15.3975, Train Accuracy: 0.7200
# Test Loss: 15.4122, Test Accuracy: 0.7183
#
# Epoch 307
# Train Loss: 15.4025, Train Accuracy: 0.7190
# Test Loss: 15.4172, Test Accuracy: 0.7183
#
# Epoch 308
# Train Loss: 15.4075, Train Accuracy: 0.7190
# Test Loss: 15.4222, Test Accuracy: 0.7183
#
# Epoch 309
# Train Loss: 15.4125, Train Accuracy: 0.7190
# Test Loss: 15.4272, Test Accuracy: 0.7183
#
# Epoch 310
# Train Loss: 15.4175, Train Accuracy: 0.7190
# Test Loss: 15.4321, Test Accuracy: 0.7178
#
# Epoch 311
# Train Loss: 15.4225, Train Accuracy: 0.7190
# Test Loss: 15.4371, Test Accuracy: 0.7178
#
# Epoch 312
# Train Loss: 15.4275, Train Accuracy: 0.7190
# Test Loss: 15.4421, Test Accuracy: 0.7178
#
# Epoch 313
# Train Loss: 15.4324, Train Accuracy: 0.7190
# Test Loss: 15.4471, Test Accuracy: 0.7178
#
# Epoch 314
# Train Loss: 15.4374, Train Accuracy: 0.7190
# Test Loss: 15.4520, Test Accuracy: 0.7178
#
# Epoch 315
# Train Loss: 15.4424, Train Accuracy: 0.7190
# Test Loss: 15.4570, Test Accuracy: 0.7178
#
# Epoch 316
# Train Loss: 15.4473, Train Accuracy: 0.7190
# Test Loss: 15.4619, Test Accuracy: 0.7178
#
# Epoch 317
# Train Loss: 15.4523, Train Accuracy: 0.7190
# Test Loss: 15.4669, Test Accuracy: 0.7178
#
# Epoch 318
# Train Loss: 15.4572, Train Accuracy: 0.7190
# Test Loss: 15.4718, Test Accuracy: 0.7178
#
# Epoch 319
# Train Loss: 15.4621, Train Accuracy: 0.7190
# Test Loss: 15.4767, Test Accuracy: 0.7178
#
# Epoch 320
# Train Loss: 15.4671, Train Accuracy: 0.7190
# Test Loss: 15.4816, Test Accuracy: 0.7183
#
# Epoch 321
# Train Loss: 15.4720, Train Accuracy: 0.7180
# Test Loss: 15.4866, Test Accuracy: 0.7189
#
# Epoch 322
# Train Loss: 15.4769, Train Accuracy: 0.7170
# Test Loss: 15.4915, Test Accuracy: 0.7189
#
# Epoch 323
# Train Loss: 15.4818, Train Accuracy: 0.7170
# Test Loss: 15.4964, Test Accuracy: 0.7189
#
# Epoch 324
# Train Loss: 15.4867, Train Accuracy: 0.7170
# Test Loss: 15.5013, Test Accuracy: 0.7189
#
# Epoch 325
# Train Loss: 15.4916, Train Accuracy: 0.7170
# Test Loss: 15.5062, Test Accuracy: 0.7200
#
# Epoch 326
# Train Loss: 15.4965, Train Accuracy: 0.7170
# Test Loss: 15.5110, Test Accuracy: 0.7206
#
# Epoch 327
# Train Loss: 15.5014, Train Accuracy: 0.7170
# Test Loss: 15.5159, Test Accuracy: 0.7206
#
# Epoch 328
# Train Loss: 15.5063, Train Accuracy: 0.7170
# Test Loss: 15.5208, Test Accuracy: 0.7200
#
# Epoch 329
# Train Loss: 15.5111, Train Accuracy: 0.7180
# Test Loss: 15.5257, Test Accuracy: 0.7206
#
# Epoch 330
# Train Loss: 15.5160, Train Accuracy: 0.7180
# Test Loss: 15.5305, Test Accuracy: 0.7206
#
# Epoch 331
# Train Loss: 15.5209, Train Accuracy: 0.7180
# Test Loss: 15.5354, Test Accuracy: 0.7217
#
# Epoch 332
# Train Loss: 15.5257, Train Accuracy: 0.7180
# Test Loss: 15.5402, Test Accuracy: 0.7217
#
# Epoch 333
# Train Loss: 15.5306, Train Accuracy: 0.7180
# Test Loss: 15.5451, Test Accuracy: 0.7223
#
# Epoch 334
# Train Loss: 15.5354, Train Accuracy: 0.7180
# Test Loss: 15.5499, Test Accuracy: 0.7223
#
# Epoch 335
# Train Loss: 15.5402, Train Accuracy: 0.7180
# Test Loss: 15.5547, Test Accuracy: 0.7223
#
# Epoch 336
# Train Loss: 15.5451, Train Accuracy: 0.7180
# Test Loss: 15.5596, Test Accuracy: 0.7217
#
# Epoch 337
# Train Loss: 15.5499, Train Accuracy: 0.7180
# Test Loss: 15.5644, Test Accuracy: 0.7217
#
# Epoch 338
# Train Loss: 15.5547, Train Accuracy: 0.7180
# Test Loss: 15.5692, Test Accuracy: 0.7212
#
# Epoch 339
# Train Loss: 15.5595, Train Accuracy: 0.7180
# Test Loss: 15.5740, Test Accuracy: 0.7212
#
# Epoch 340
# Train Loss: 15.5643, Train Accuracy: 0.7180
# Test Loss: 15.5788, Test Accuracy: 0.7212
#
# Epoch 341
# Train Loss: 15.5691, Train Accuracy: 0.7180
# Test Loss: 15.5836, Test Accuracy: 0.7212
#
# Epoch 342
# Train Loss: 15.5739, Train Accuracy: 0.7180
# Test Loss: 15.5884, Test Accuracy: 0.7217
#
# Epoch 343
# Train Loss: 15.5787, Train Accuracy: 0.7190
# Test Loss: 15.5931, Test Accuracy: 0.7217
#
# Epoch 344
# Train Loss: 15.5835, Train Accuracy: 0.7190
# Test Loss: 15.5979, Test Accuracy: 0.7217
#
# Epoch 345
# Train Loss: 15.5882, Train Accuracy: 0.7190
# Test Loss: 15.6027, Test Accuracy: 0.7217
#
# Epoch 346
# Train Loss: 15.5930, Train Accuracy: 0.7200
# Test Loss: 15.6074, Test Accuracy: 0.7217
#
# Epoch 347
# Train Loss: 15.5978, Train Accuracy: 0.7200
# Test Loss: 15.6122, Test Accuracy: 0.7217
#
# Epoch 348
# Train Loss: 15.6025, Train Accuracy: 0.7200
# Test Loss: 15.6170, Test Accuracy: 0.7217
#
# Epoch 349
# Train Loss: 15.6073, Train Accuracy: 0.7200
# Test Loss: 15.6217, Test Accuracy: 0.7217
#
# Epoch 350
# Train Loss: 15.6120, Train Accuracy: 0.7200
# Test Loss: 15.6264, Test Accuracy: 0.7217
#
# Epoch 351
# Train Loss: 15.6168, Train Accuracy: 0.7200
# Test Loss: 15.6312, Test Accuracy: 0.7223
#
# Epoch 352
# Train Loss: 15.6215, Train Accuracy: 0.7200
# Test Loss: 15.6359, Test Accuracy: 0.7223
#
# Epoch 353
# Train Loss: 15.6262, Train Accuracy: 0.7200
# Test Loss: 15.6406, Test Accuracy: 0.7223
#
# Epoch 354
# Train Loss: 15.6309, Train Accuracy: 0.7190
# Test Loss: 15.6453, Test Accuracy: 0.7223
#
# Epoch 355
# Train Loss: 15.6357, Train Accuracy: 0.7180
# Test Loss: 15.6500, Test Accuracy: 0.7229
#
# Epoch 356
# Train Loss: 15.6404, Train Accuracy: 0.7180
# Test Loss: 15.6547, Test Accuracy: 0.7223
#
# Epoch 357
# Train Loss: 15.6451, Train Accuracy: 0.7180
# Test Loss: 15.6594, Test Accuracy: 0.7223
#
# Epoch 358
# Train Loss: 15.6498, Train Accuracy: 0.7180
# Test Loss: 15.6641, Test Accuracy: 0.7217
#
# Epoch 359
# Train Loss: 15.6545, Train Accuracy: 0.7180
# Test Loss: 15.7796, Test Accuracy: 0.7234
#
# Epoch 384
# Train Loss: 15.7699, Train Accuracy: 0.7140
# Test Loss: 15.7841, Test Accuracy: 0.7234
#
# Epoch 385
# Train Loss: 15.7744, Train Accuracy: 0.7140
# Test Loss: 15.7887, Test Accuracy: 0.7234
#
# Epoch 386
# Train Loss: 15.7790, Train Accuracy: 0.7140
# Test Loss: 15.7932, Test Accuracy: 0.7234
#
# Epoch 387
# Train Loss: 15.7835, Train Accuracy: 0.7140
# Test Loss: 15.7977, Test Accuracy: 0.7240
#
# Epoch 388
# Train Loss: 15.7880, Train Accuracy: 0.7140
# Test Loss: 15.8023, Test Accuracy: 0.7240
#
# Epoch 389
# Train Loss: 15.7926, Train Accuracy: 0.7140
# Test Loss: 15.8068, Test Accuracy: 0.7240
#
# Epoch 390
# Train Loss: 15.7971, Train Accuracy: 0.7140
# Test Loss: 15.8113, Test Accuracy: 0.7245
#
# Epoch 391
# Train Loss: 15.8016, Train Accuracy: 0.7140
# Test Loss: 15.8158, Test Accuracy: 0.7251
#
# Epoch 392
# Train Loss: 15.8061, Train Accuracy: 0.7140
# Test Loss: 15.8203, Test Accuracy: 0.7251
#
# Epoch 393
# Train Loss: 15.8106, Train Accuracy: 0.7140
# Test Loss: 15.8248, Test Accuracy: 0.7251
#
# Epoch 394
# Train Loss: 15.8151, Train Accuracy: 0.7150
# Test Loss: 15.8293, Test Accuracy: 0.7251
#
# Epoch 395
# Train Loss: 15.8196, Train Accuracy: 0.7150
# Test Loss: 15.8338, Test Accuracy: 0.7245
#
# Epoch 396
# Train Loss: 15.8241, Train Accuracy: 0.7150
# Test Loss: 15.8383, Test Accuracy: 0.7251
#
# Epoch 397
# Train Loss: 15.8285, Train Accuracy: 0.7150
# Test Loss: 15.8427, Test Accuracy: 0.7251
#
# Epoch 398
# Train Loss: 15.8330, Train Accuracy: 0.7150
# Test Loss: 15.8472, Test Accuracy: 0.7251
#
# Epoch 399
# Train Loss: 15.8375, Train Accuracy: 0.7150
# Test Loss: 15.8517, Test Accuracy: 0.7257
#
# Epoch 400
# Train Loss: 15.8419, Train Accuracy: 0.7150
# Test Loss: 15.8561, Test Accuracy: 0.7257
#
# Epoch 401
# Train Loss: 15.8464, Train Accuracy: 0.7140
# Test Loss: 15.8606, Test Accuracy: 0.7257
#
# Epoch 402
# Train Loss: 15.8509, Train Accuracy: 0.7140
# Test Loss: 15.8650, Test Accuracy: 0.7257
#
# Epoch 403
# Train Loss: 15.8553, Train Accuracy: 0.7140
# Test Loss: 15.8695, Test Accuracy: 0.7257
#
# Epoch 404
# Train Loss: 15.8597, Train Accuracy: 0.7140
# Test Loss: 15.8739, Test Accuracy: 0.7257
#
# Epoch 405
# Train Loss: 15.8642, Train Accuracy: 0.7140
# Test Loss: 15.8783, Test Accuracy: 0.7257
#
# Epoch 406
# Train Loss: 15.8686, Train Accuracy: 0.7140
# Test Loss: 15.8828, Test Accuracy: 0.7257
#
# Epoch 407
#
# Epoch 431
# Train Loss: 15.9777, Train Accuracy: 0.7180
# Test Loss: 15.9917, Test Accuracy: 0.7313
#
# Epoch 432
# Train Loss: 15.9820, Train Accuracy: 0.7180
# Test Loss: 15.9960, Test Accuracy: 0.7313
#
# Epoch 433
# Train Loss: 15.9863, Train Accuracy: 0.7180
# Test Loss: 16.0003, Test Accuracy: 0.7313
#
# Epoch 434
# Train Loss: 15.9906, Train Accuracy: 0.7180
# Test Loss: 16.0046, Test Accuracy: 0.7313
#
# Epoch 435
# Train Loss: 15.9949, Train Accuracy: 0.7180
# Test Loss: 16.0089, Test Accuracy: 0.7313
#
# Epoch 436
# Train Loss: 15.9992, Train Accuracy: 0.7180
# Test Loss: 16.0132, Test Accuracy: 0.7313
#
# Epoch 437
# Train Loss: 16.0034, Train Accuracy: 0.7180
# Test Loss: 16.0174, Test Accuracy: 0.7313
#
# Epoch 438
# Train Loss: 16.0077, Train Accuracy: 0.7180
# Test Loss: 16.0217, Test Accuracy: 0.7313
#
# Epoch 439
# Train Loss: 16.0120, Train Accuracy: 0.7180
# Test Loss: 16.0260, Test Accuracy: 0.7313
#
# Epoch 440
# Train Loss: 16.0162, Train Accuracy: 0.7180
# Test Loss: 16.0302, Test Accuracy: 0.7313
#
# Epoch 441
# Train Loss: 16.0205, Train Accuracy: 0.7180
# Test Loss: 16.0345, Test Accuracy: 0.7319
#
# Epoch 442
# Train Loss: 16.0247, Train Accuracy: 0.7180
# Test Loss: 16.0387, Test Accuracy: 0.7325
#
# Epoch 443
# Train Loss: 16.0290, Train Accuracy: 0.7180
# Test Loss: 16.0429, Test Accuracy: 0.7325
#
# Epoch 444
# Train Loss: 16.0332, Train Accuracy: 0.7180
# Test Loss: 16.0472, Test Accuracy: 0.7325
#
# Epoch 445
# Train Loss: 16.0374, Train Accuracy: 0.7180
# Test Loss: 16.0514, Test Accuracy: 0.7325
#
# Epoch 446
# Train Loss: 16.0417, Train Accuracy: 0.7180
# Test Loss: 16.0556, Test Accuracy: 0.7325
#
# Epoch 447
# Train Loss: 16.0459, Train Accuracy: 0.7190
# Test Loss: 16.0599, Test Accuracy: 0.7325
#
# Epoch 448
# Train Loss: 16.0501, Train Accuracy: 0.7190
# Test Loss: 16.0641, Test Accuracy: 0.7325
#
# Epoch 449
# Train Loss: 16.0543, Train Accuracy: 0.7190
# Test Loss: 16.0683, Test Accuracy: 0.7330
#
# Epoch 450
# Train Loss: 16.0585, Train Accuracy: 0.7190
# Test Loss: 16.0725, Test Accuracy: 0.7330
#
# Epoch 451
# Train Loss: 16.0627, Train Accuracy: 0.7190
# Test Loss: 16.0767, Test Accuracy: 0.7330
#
# Epoch 452
# Train Loss: 16.0669, Train Accuracy: 0.7190
# Test Loss: 16.0809, Test Accuracy: 0.7325
#
# Epoch 453
# Train Loss: 16.0711, Train Accuracy: 0.7190
# Test Loss: 16.0851, Test Accuracy: 0.7325
#
# Epoch 454
# Train Loss: 16.0753, Train Accuracy: 0.7190
# Test Loss: 16.0893, Test Accuracy: 0.7325
#
# Epoch 455
# Train Loss: 16.0795, Train Accuracy: 0.7190
# Test Loss: 16.0934, Test Accuracy: 0.7330
#
# Epoch 456
# Train Loss: 16.0837, Train Accuracy: 0.7190
# Test Loss: 16.0976, Test Accuracy: 0.7330
#
# Epoch 457
# Train Loss: 16.0879, Train Accuracy: 0.7190
# Test Loss: 16.1018, Test Accuracy: 0.7330
#
# Epoch 458
# Train Loss: 16.0920, Train Accuracy: 0.7190
# Test Loss: 16.1060, Test Accuracy: 0.7330
#
# Epoch 459
# Train Loss: 16.0962, Train Accuracy: 0.7190
# Test Loss: 16.1101, Test Accuracy: 0.7330
#
# Epoch 460
# Train Loss: 16.1004, Train Accuracy: 0.7190
# Test Loss: 16.1143, Test Accuracy: 0.7330
#
# Epoch 461
# Train Loss: 16.1045, Train Accuracy: 0.7190
# Test Loss: 16.1184, Test Accuracy: 0.7342
#
# Epoch 462
# Train Loss: 16.1087, Train Accuracy: 0.7190
# Test Loss: 16.1226, Test Accuracy: 0.7342
#
# Epoch 463
# Train Loss: 16.1128, Train Accuracy: 0.7190
# Test Loss: 16.1267, Test Accuracy: 0.7347
#
# Epoch 464
# Train Loss: 16.1170, Train Accuracy: 0.7190
# Test Loss: 16.1309, Test Accuracy: 0.7347
#
# Epoch 465
# Train Loss: 16.1211, Train Accuracy: 0.7190
# Test Loss: 16.1350, Test Accuracy: 0.7353
#
# Epoch 466
# Train Loss: 16.1252, Train Accuracy: 0.7190
# Test Loss: 16.1391, Test Accuracy: 0.7353
#
# Epoch 467
# Train Loss: 16.1294, Train Accuracy: 0.7190
# Test Loss: 16.1433, Test Accuracy: 0.7353
#
# Epoch 468
# Train Loss: 16.1335, Train Accuracy: 0.7200
# Test Loss: 16.1474, Test Accuracy: 0.7353
#
# Epoch 469
# Train Loss: 16.1376, Train Accuracy: 0.7200
# Test Loss: 16.1515, Test Accuracy: 0.7353
#
# Epoch 470
# Train Loss: 16.1417, Train Accuracy: 0.7200
# Test Loss: 16.1556, Test Accuracy: 0.7353
#
# Epoch 471
# Train Loss: 16.1458, Train Accuracy: 0.7200
# Test Loss: 16.1597, Test Accuracy: 0.7353
#
# Epoch 472
# Train Loss: 16.1499, Train Accuracy: 0.7200
# Test Loss: 16.1638, Test Accuracy: 0.7353
#
# Epoch 473
# Train Loss: 16.1540, Train Accuracy: 0.7200
# Test Loss: 16.1679, Test Accuracy: 0.7353
#
# Epoch 474
# Train Loss: 16.1581, Train Accuracy: 0.7200
# Test Loss: 16.1720, Test Accuracy: 0.7353
#
# Epoch 475
# Train Loss: 16.1622, Train Accuracy: 0.7200
# Test Loss: 16.1761, Test Accuracy: 0.7347
#
# Epoch 476
# Train Loss: 16.1663, Train Accuracy: 0.7200
# Test Loss: 16.1802, Test Accuracy: 0.7347
#
# Epoch 477
# Train Loss: 16.1704, Train Accuracy: 0.7200
# Test Loss: 16.1842, Test Accuracy: 0.7347
#
# Epoch 478
# Train Loss: 16.1745, Train Accuracy: 0.7200
# Test Loss: 16.1883, Test Accuracy: 0.7347
#
# Epoch 479
# Train Loss: 16.1785, Train Accuracy: 0.7200
# Test Loss: 16.1924, Test Accuracy: 0.7347
#
# Epoch 480
# Train Loss: 16.1826, Train Accuracy: 0.7200
# Test Loss: 16.1965, Test Accuracy: 0.7347
#
# Epoch 481
# Train Loss: 16.1867, Train Accuracy: 0.7200
# Test Loss: 16.2005, Test Accuracy: 0.7347
#
# Epoch 482
# Train Loss: 16.1907, Train Accuracy: 0.7200
# Test Loss: 16.2046, Test Accuracy: 0.7342
#
# Epoch 483
# Train Loss: 16.1948, Train Accuracy: 0.7200
# Test Loss: 16.2086, Test Accuracy: 0.7342
#
# Epoch 484
# Train Loss: 16.1988, Train Accuracy: 0.7210
# Test Loss: 16.2127, Test Accuracy: 0.7342
#
# Epoch 485
# Train Loss: 16.2029, Train Accuracy: 0.7210
# Test Loss: 16.2167, Test Accuracy: 0.7342
#
# Epoch 486
# Train Loss: 16.2069, Train Accuracy: 0.7210
# Test Loss: 16.2208, Test Accuracy: 0.7342
#
# Epoch 487
# Train Loss: 16.2110, Train Accuracy: 0.7210
# Test Loss: 16.2248, Test Accuracy: 0.7342
#
# Epoch 488
# Train Loss: 16.2150, Train Accuracy: 0.7210
# Test Loss: 16.2288, Test Accuracy: 0.7347
#
# Epoch 489
# Train Loss: 16.2190, Train Accuracy: 0.7210
# Test Loss: 16.2328, Test Accuracy: 0.7353
#
# Epoch 490
# Train Loss: 16.2230, Train Accuracy: 0.7210
# Test Loss: 16.2369, Test Accuracy: 0.7347
#
# Epoch 491
# Train Loss: 16.2271, Train Accuracy: 0.7210
# Test Loss: 16.2409, Test Accuracy: 0.7347
#
# Epoch 492
# Train Loss: 16.2311, Train Accuracy: 0.7210
# Test Loss: 16.2449, Test Accuracy: 0.7347
#
# Epoch 493
# Train Loss: 16.2351, Train Accuracy: 0.7210
# Test Loss: 16.2489, Test Accuracy: 0.7353
#
# Epoch 494
# Train Loss: 16.2391, Train Accuracy: 0.7210
# Test Loss: 16.2529, Test Accuracy: 0.7353
#
# Epoch 495
# Train Loss: 16.2431, Train Accuracy: 0.7210
# Test Loss: 16.2569, Test Accuracy: 0.7347
#
# Epoch 496
# Train Loss: 16.2471, Train Accuracy: 0.7210
# Test Loss: 16.2609, Test Accuracy: 0.7347
#
# Epoch 497
# Train Loss: 16.2511, Train Accuracy: 0.7210
# Test Loss: 16.2649, Test Accuracy: 0.7353
#
# Epoch 498
# Train Loss: 16.2551, Train Accuracy: 0.7210
# Test Loss: 16.2689, Test Accuracy: 0.7353
#
# Epoch 499
# Train Loss: 16.2591, Train Accuracy: 0.7210
# Test Loss: 16.2728, Test Accuracy: 0.7353
#
# Epoch 500
# Train Loss: 16.2630, Train Accuracy: 0.7210
# Test Loss: 16.2768, Test Accuracy: 0.7353

# %% [markdown]
# ## Result

# %%
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.title("Loss per Epoch - Stacked GRU")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(train_accuracies, label="Train Accuracy")
plt.plot(test_accuracies, label="Test Accuracy")
plt.title("Accuracy per Epoch - Stacked GRU")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # DL - HM02.3

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
from sklearn.datasets import fetch_openml
from sklearn.datasets import fetch_openml
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Hyperparameters

# %%
class Hyperparameters:
    INPUT_SIZE = 784
    ENC1_SIZE = 256     # Rough Layer
    ENC2_SIZE = 128
    BOTTLENECK_SIZE = 64
    DEC2_SIZE = 128
    DEC1_SIZE = 256
    MLP_HIDDEN_SIZE = 128
    OUTPUT_SIZE = 10
    
    LEARNING_RATE_PAIR1 = 0.001 
    NUM_EPOCHS_PAIR1 = 15
    
    LEARNING_RATE_PAIR2 = 0.001
    NUM_EPOCHS_PAIR2 = 100
    
    LEARNING_RATE_PAIR3 = 0.001
    NUM_EPOCHS_PAIR3 = 100
    
    LEARNING_RATE_MLP = 0.001
    NUM_EPOCHS_MLP = 500
    
    NOISE_FACTOR = 0.5
    LEAKY_RELU_ALPHA = 0.01
    
    TRAIN_RATIO = 0.70
    VAL_RATIO = 0.10
    TEST_RATIO = 0.20
    
    ACT_ENC1 = "sigmoid"      # Rough Layer
    ACT_ENC2 = "leaky_relu"
    ACT_ENC3 = "leaky_relu"
    ACT_DEC1 = "leaky_relu"
    ACT_DEC2 = "leaky_relu"
    ACT_DEC3 = "sigmoid"
    ACT_MLP1 = "leaky_relu"
    ACT_MLP2 = "softmax"      # تغییر به سافت‌مکس

# %%
HP = Hyperparameters()

# %% [markdown]
# ## Functions

# %%
# def sigmoid_activation(x):
#     return 1 / (1 + np.exp(-x))

def sigmoid_activation(x):
    # نسخه پایدارتر برای جلوگیری از سرریز
    x = np.clip(x, -500, 500)
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    sig = sigmoid_activation(x)
    return sig * (1 - sig)

def relu_activation(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return np.where(x > 0, 1, 0)

def leaky_relu_activation(x, alpha=HP.LEAKY_RELU_ALPHA):
    x = np.clip(x, -100, 100)  # clipping to prevent overflow
    return np.where(x > 0, x, alpha * x)

def leaky_relu_derivative(x, alpha=HP.LEAKY_RELU_ALPHA):
    x = np.clip(x, -100, 100)  # clipping to prevent overflow
    return np.where(x > 0, 1, alpha)

def purelin_activation(x):
    return x

def purelin_derivative(x):
    return np.ones_like(x)

def softmax_activation(x):
    exp_x = np.exp(x - np.max(x))  # برای پایداری عددی
    return exp_x / np.sum(exp_x)

def softmax_derivative(x):
    # مشتق سافت‌مکس به صورت دقیق برای backpropagation
    s = softmax_activation(x)
    return s * (1 - s)  # تقریبی ساده برای محاسبات

# %%
def get_activation(x, activation_name):
    if activation_name == "relu":
        return relu_activation(x)

    elif activation_name == "leaky_relu":
        return leaky_relu_activation(x)
        
    elif activation_name == "sigmoid":
        return sigmoid_activation(x)
        
    elif activation_name == "purelin":
        return purelin_activation(x)
    
    elif activation_name == "softmax":
        return softmax_activation(x)
    
    else:
        raise ValueError(f"Unknown activation: {activation_name}")

# %%
def get_derivative(x, activation_name):
    if activation_name == "relu":
        return relu_derivative(x)

    elif activation_name == "leaky_relu":
        return leaky_relu_derivative(x)
        
    elif activation_name == "sigmoid":
        return sigmoid_derivative(x)
        
    elif activation_name == "purelin":
        return purelin_derivative(x)
    
    elif activation_name == "softmax":
        return softmax_derivative(x)
    
    else:
        raise ValueError(f"Unknown derivative: {activation_name}")

# %% [markdown]
# ## Fetch data

# %%
mnist = fetch_openml('mnist_784', version=1, cache=True, as_frame=False)
X_raw, y_labels = mnist["data"], mnist["target"].astype(np.int32)

# %% [markdown]
# ## Normalize

# %%
X_raw = X_raw / 255.0

# %% [markdown]
# ## One-Hot encoding

# %%
y_one_hot = np.zeros((y_labels.shape[0], HP.OUTPUT_SIZE))
for i, label in enumerate(y_labels):
    y_one_hot[i, label] = 1

# %% [markdown]
# ## Train/Test split

# %%
total_samples = X_raw.shape[0]
num_train = int(total_samples * HP.TRAIN_RATIO)
num_val = int(total_samples * HP.VAL_RATIO)
num_test = total_samples - num_train - num_val

# %% [markdown]
# ## Shuflling

# %%
indices = np.random.permutation(total_samples)
X_shuffled = X_raw[indices]
y_shuffled = y_one_hot[indices]
y_labels_shuffled = y_labels[indices]

# %% [markdown]
# ## Pure data

# %%
X_train_clean = X_shuffled[:num_train]
y_train = y_shuffled[:num_train]
y_train_labels = y_labels_shuffled[:num_train]
X_val_clean = X_shuffled[num_train:num_train+num_val]
y_val = y_shuffled[num_train:num_train+num_val]
y_val_labels = y_labels_shuffled[num_train:num_train+num_val]
X_test_clean = X_shuffled[num_train+num_val:]
y_test = y_shuffled[num_train+num_val:]
y_test_labels = y_labels_shuffled[num_train+num_val:]

# %% [markdown]
# ## Add Noise

# %%
X_train_noisy = X_train_clean + HP.NOISE_FACTOR * np.random.normal(loc=0.0, scale=1.0, size=X_train_clean.shape)
X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_val_noisy = X_val_clean + HP.NOISE_FACTOR * np.random.normal(loc=0.0, scale=1.0, size=X_val_clean.shape)
X_val_noisy = np.clip(X_val_noisy, 0., 1.)
X_test_noisy = X_test_clean + HP.NOISE_FACTOR * np.random.normal(loc=0.0, scale=1.0, size=X_test_clean.shape)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)

# %% [markdown]
# ## Initialization wheights

# %% [markdown]
# ### AutoEncoder

# %%
w_enc1_upper = np.random.uniform(-0.5, 0.5, (HP.ENC1_SIZE, HP.INPUT_SIZE))
b_enc1_upper = np.zeros(HP.ENC1_SIZE)
w_enc1_lower = np.random.uniform(-0.5, 0.5, (HP.ENC1_SIZE, HP.INPUT_SIZE))
b_enc1_lower = np.zeros(HP.ENC1_SIZE)
w_dec1 = np.random.uniform(-0.5, 0.5, (HP.INPUT_SIZE, HP.ENC1_SIZE))
b_dec1 = np.zeros(HP.INPUT_SIZE)

w_enc2 = np.random.uniform(-0.5, 0.5, (HP.ENC2_SIZE, HP.ENC1_SIZE))
b_enc2 = np.zeros(HP.ENC2_SIZE)
w_dec2 = np.random.uniform(-0.5, 0.5, (HP.INPUT_SIZE, HP.ENC2_SIZE)) 
b_dec2 = np.zeros(HP.INPUT_SIZE)

w_enc3 = np.random.uniform(-0.5, 0.5, (HP.BOTTLENECK_SIZE, HP.ENC2_SIZE))
b_enc3 = np.zeros(HP.BOTTLENECK_SIZE)
w_dec3 = np.random.uniform(-0.5, 0.5, (HP.INPUT_SIZE, HP.BOTTLENECK_SIZE))
b_dec3 = np.zeros(HP.INPUT_SIZE)

# %% [markdown]
# ### MLP

# %%
w_mlp1 = np.random.uniform(-0.5, 0.5, (HP.MLP_HIDDEN_SIZE, HP.BOTTLENECK_SIZE))
b_mlp1 = np.zeros(HP.MLP_HIDDEN_SIZE)
w_mlp2 = np.random.uniform(-0.5, 0.5, (HP.OUTPUT_SIZE, HP.MLP_HIDDEN_SIZE))
b_mlp2 = np.zeros(HP.OUTPUT_SIZE)

# %% [markdown]
# ## Trainning

# %%
def train_rough_layer(input_data, target, learning_rate):
    global w_enc1_upper, b_enc1_upper, w_enc1_lower, b_enc1_lower, w_dec1, b_dec1
    
    net_enc1_upper = np.dot(w_enc1_upper, input_data) + b_enc1_upper
    out_enc1_upper = get_activation(net_enc1_upper, HP.ACT_ENC1)
    net_enc1_lower = np.dot(w_enc1_lower, input_data) + b_enc1_lower
    out_enc1_lower = get_activation(net_enc1_lower, HP.ACT_ENC1)
    out_enc1 = (out_enc1_upper + out_enc1_lower) / 2.0
    
    net_dec1 = np.dot(w_dec1, out_enc1) + b_dec1
    out_dec1 = get_activation(net_dec1, HP.ACT_DEC3)
    
    error_dec1 = target - out_dec1
    delta_dec1 = error_dec1 * get_derivative(net_dec1, HP.ACT_DEC3)
    delta_enc1 = np.dot(w_dec1.T, delta_dec1) * get_derivative(out_enc1, HP.ACT_ENC1)
    
    delta_enc1_upper = delta_enc1 * 0.5
    delta_enc1_lower = delta_enc1 * 0.5
    
    w_dec1 += learning_rate * np.outer(delta_dec1, out_enc1)
    b_dec1 += learning_rate * delta_dec1
    w_enc1_upper += learning_rate * np.outer(delta_enc1_upper, input_data)
    b_enc1_upper += learning_rate * delta_enc1_upper
    w_enc1_lower += learning_rate * np.outer(delta_enc1_lower, input_data)
    b_enc1_lower += learning_rate * delta_enc1_lower
    
    return out_enc1, out_dec1, np.mean(error_dec1 ** 2)

# %%
def train_layer_pair(input_data, target, w_enc, b_enc, w_dec, b_dec, act_enc, act_dec, learning_rate):
    net_enc = np.dot(w_enc, input_data) + b_enc
    out_enc = get_activation(net_enc, act_enc)
    
    net_dec = np.dot(w_dec, out_enc) + b_dec
    out_dec = get_activation(net_dec, act_dec)
    
    error_dec = target - out_dec
    delta_dec = error_dec * get_derivative(net_dec, act_dec)
    delta_enc = np.dot(w_dec.T, delta_dec) * get_derivative(net_enc, act_enc)
    
    w_dec += learning_rate * np.outer(delta_dec, out_enc)
    b_dec += learning_rate * delta_dec
    w_enc += learning_rate * np.outer(delta_enc, input_data)
    b_enc += learning_rate * delta_enc
    
    return out_enc, out_dec, np.mean(error_dec ** 2)

# %%
def train_mlp(bottleneck, target, learning_rate):
    global w_mlp1, b_mlp1, w_mlp2, b_mlp2
    
    # Forward pass
    net_mlp1 = np.dot(w_mlp1, bottleneck) + b_mlp1
    out_mlp1 = get_activation(net_mlp1, HP.ACT_MLP1)
    
    net_mlp2 = np.dot(w_mlp2, out_mlp1) + b_mlp2
    out_mlp2 = get_activation(net_mlp2, HP.ACT_MLP2)  # حالا سافت‌مکس است
    
    # محاسبه خطا (cross-entropy loss)
    error_mlp2 = target - out_mlp2  # برای سافت‌مکس، خطا مستقیماً محاسبه می‌شود
    delta_mlp2 = error_mlp2  # مشتق سافت‌مکس با cross-entropy ساده می‌شود
    
    # Backpropagation
    error_mlp1 = np.dot(w_mlp2.T, delta_mlp2)
    delta_mlp1 = error_mlp1 * get_derivative(net_mlp1, HP.ACT_MLP1)
    
    # به‌روزرسانی وزن‌ها و بایاس‌ها
    w_mlp2 += learning_rate * np.outer(delta_mlp2, out_mlp1)
    b_mlp2 += learning_rate * delta_mlp2
    w_mlp1 += learning_rate * np.outer(delta_mlp1, bottleneck)
    b_mlp1 += learning_rate * delta_mlp1
    
    return out_mlp2

# %%
def full_feedforward_encoder(input_data):
    net_enc1_upper = np.dot(w_enc1_upper, input_data) + b_enc1_upper
    out_enc1_upper = get_activation(net_enc1_upper, HP.ACT_ENC1)
    net_enc1_lower = np.dot(w_enc1_lower, input_data) + b_enc1_lower
    out_enc1_lower = get_activation(net_enc1_lower, HP.ACT_ENC1)
    out_enc1 = (out_enc1_upper + out_enc1_lower) / 2.0
    
    net_enc2 = np.dot(w_enc2, out_enc1) + b_enc2
    out_enc2 = get_activation(net_enc2, HP.ACT_ENC2)
    
    net_enc3 = np.dot(w_enc3, out_enc2) + b_enc3
    out_enc3 = get_activation(net_enc3, HP.ACT_ENC3)
    
    return out_enc3

# %% [markdown]
# ### History memory

# %%
train_mse_history = {
    "Pair_1": np.zeros(HP.NUM_EPOCHS_PAIR1),
    "Pair_2": np.zeros(HP.NUM_EPOCHS_PAIR2),
    "Pair_3": np.zeros(HP.NUM_EPOCHS_PAIR3)
}
val_mse_history = {
    "Pair_1": np.zeros(HP.NUM_EPOCHS_PAIR1),
    "Pair_2": np.zeros(HP.NUM_EPOCHS_PAIR2),
    "Pair_3": np.zeros(HP.NUM_EPOCHS_PAIR3)
}
train_acc_history = np.zeros(HP.NUM_EPOCHS_MLP)
val_acc_history = np.zeros(HP.NUM_EPOCHS_MLP)

# %% [markdown]
# ### Autoencoder

# %%
weights_history_pair1 = {
    "w_enc1_upper": [],
    "b_enc1_upper": [],
    "w_enc1_lower": [],
    "b_enc1_lower": [],
    "w_dec1": [],
    "b_dec1": [],
    "val_mse": []
}

# %%
# Pair 1: ENC1 (Rough) + DEC1
for epoch in range(HP.NUM_EPOCHS_PAIR1):
    train_loss = 0
    val_loss = 0
    for i in range(num_train):
        _, _, mse = train_rough_layer(X_train_noisy[i], X_train_clean[i], HP.LEARNING_RATE_PAIR1)
        train_loss += mse
    for i in range(num_val):
        out_enc1 = (get_activation(np.dot(w_enc1_upper, X_val_noisy[i]) + b_enc1_upper, HP.ACT_ENC1) +
                    get_activation(np.dot(w_enc1_lower, X_val_noisy[i]) + b_enc1_lower, HP.ACT_ENC1)) / 2.0
        out_dec1 = get_activation(np.dot(w_dec1, out_enc1) + b_dec1, HP.ACT_DEC3)
        val_loss += np.mean((X_val_clean[i] - out_dec1) ** 2)
    
    train_mse_history["Pair_1"][epoch] = train_loss / num_train
    val_mse_history["Pair_1"][epoch] = val_loss / num_val
    
    # ذخیره وزن‌ها و خطای اعتبارسنجی
    weights_history_pair1["w_enc1_upper"].append(w_enc1_upper.copy())
    weights_history_pair1["b_enc1_upper"].append(b_enc1_upper.copy())
    weights_history_pair1["w_enc1_lower"].append(w_enc1_lower.copy())
    weights_history_pair1["b_enc1_lower"].append(b_enc1_lower.copy())
    weights_history_pair1["w_dec1"].append(w_dec1.copy())
    weights_history_pair1["b_dec1"].append(b_dec1.copy())
    weights_history_pair1["val_mse"].append(val_mse_history["Pair_1"][epoch])
    
    print(f"Epoch {epoch+1}/{HP.NUM_EPOCHS_PAIR1}, Train MSE: {train_mse_history['Pair_1'][epoch]:.4f}, Val MSE: {val_mse_history['Pair_1'][epoch]:.4f}")
# Out:
# Epoch 1/15, Train MSE: 0.0660, Val MSE: 0.0507
# Epoch 2/15, Train MSE: 0.0452, Val MSE: 0.0420
# Epoch 3/15, Train MSE: 0.0402, Val MSE: 0.0393
# Epoch 4/15, Train MSE: 0.0384, Val MSE: 0.0380
# Epoch 5/15, Train MSE: 0.0378, Val MSE: 0.0383
# Epoch 6/15, Train MSE: 0.0384, Val MSE: 0.0386
# Epoch 7/15, Train MSE: 0.0380, Val MSE: 0.0379
# Epoch 8/15, Train MSE: 0.0374, Val MSE: 0.0373
# Epoch 9/15, Train MSE: 0.0368, Val MSE: 0.0366
# Epoch 10/15, Train MSE: 0.0362, Val MSE: 0.0364
# Epoch 11/15, Train MSE: 0.0364, Val MSE: 0.0368
# Epoch 12/15, Train MSE: 0.0368, Val MSE: 0.0370
# Epoch 13/15, Train MSE: 0.0367, Val MSE: 0.0369
# Epoch 14/15, Train MSE: 0.0368, Val MSE: 0.0374
# Epoch 15/15, Train MSE: 0.0378, Val MSE: 0.0384

# %%
# انتخاب بهترین وزن‌ها بر اساس کمترین خطای اعتبارسنجی
best_epoch = np.argmin(weights_history_pair1["val_mse"])
w_enc1_upper = weights_history_pair1["w_enc1_upper"][best_epoch]
b_enc1_upper = weights_history_pair1["b_enc1_upper"][best_epoch]
w_enc1_lower = weights_history_pair1["w_enc1_lower"][best_epoch]
b_enc1_lower = weights_history_pair1["b_enc1_lower"][best_epoch]
w_dec1 = weights_history_pair1["w_dec1"][best_epoch]
b_dec1 = weights_history_pair1["b_dec1"][best_epoch]
print(f"Best weights for Pair 1 selected from epoch {best_epoch + 1} with Val MSE: {weights_history_pair1['val_mse'][best_epoch]:.4f}")
# Out:
# Best weights for Pair 1 selected from epoch 10 with Val MSE: 0.0364

# %%
# محاسبه خروجی‌های Encoder 1 با بهترین وزن‌ها
enc1_outputs_train = np.zeros((num_train, HP.ENC1_SIZE))
enc1_outputs_val = np.zeros((num_val, HP.ENC1_SIZE))
for i in range(num_train):
    enc1_outputs_train[i] = (get_activation(np.dot(w_enc1_upper, X_train_noisy[i]) + b_enc1_upper, HP.ACT_ENC1) +
                            get_activation(np.dot(w_enc1_lower, X_train_noisy[i]) + b_enc1_lower, HP.ACT_ENC1)) / 2.0
for i in range(num_val):
    enc1_outputs_val[i] = (get_activation(np.dot(w_enc1_upper, X_val_noisy[i]) + b_enc1_upper, HP.ACT_ENC1) +
                          get_activation(np.dot(w_enc1_lower, X_val_noisy[i]) + b_enc1_lower, HP.ACT_ENC1)) / 2.0

# %%
weights_history_pair2 = {
    "w_enc2": [],
    "b_enc2": [],
    "w_dec2": [],
    "b_dec2": [],
    "val_mse": []
}

# %%
# Pair 2: ENC2 + DEC2
for epoch in range(HP.NUM_EPOCHS_PAIR2):
    train_loss = 0
    val_loss = 0
    for i in range(num_train):
        _, _, mse = train_layer_pair(enc1_outputs_train[i], X_train_clean[i], w_enc2, b_enc2, w_dec2, b_dec2, HP.ACT_ENC2, HP.ACT_DEC3, HP.LEARNING_RATE_PAIR2)
        train_loss += mse
    for i in range(num_val):
        out_enc2 = get_activation(np.dot(w_enc2, enc1_outputs_val[i]) + b_enc2, HP.ACT_ENC2)
        out_dec2 = get_activation(np.dot(w_dec2, out_enc2) + b_dec2, HP.ACT_DEC3)
        val_loss += np.mean((X_val_clean[i] - out_dec2) ** 2)
    
    train_mse_history["Pair_2"][epoch] = train_loss / num_train
    val_mse_history["Pair_2"][epoch] = val_loss / num_val
    
    # ذخیره وزن‌ها و خطای اعتبارسنجی
    weights_history_pair2["w_enc2"].append(w_enc2.copy())
    weights_history_pair2["b_enc2"].append(b_enc2.copy())
    weights_history_pair2["w_dec2"].append(w_dec2.copy())
    weights_history_pair2["b_dec2"].append(b_dec2.copy())
    weights_history_pair2["val_mse"].append(val_mse_history["Pair_2"][epoch])
    
    print(f"Epoch {epoch+1}/{HP.NUM_EPOCHS_PAIR2}, Train MSE: {train_mse_history['Pair_2'][epoch]:.4f}, Val MSE: {val_mse_history['Pair_2'][epoch]:.4f}")
# Out:
# Epoch 1/100, Train MSE: 0.0622, Val MSE: 0.0466
# Epoch 2/100, Train MSE: 0.0439, Val MSE: 0.0424
# Epoch 3/100, Train MSE: 0.0405, Val MSE: 0.0391
# Epoch 4/100, Train MSE: 0.0381, Val MSE: 0.0366
# Epoch 5/100, Train MSE: 0.0361, Val MSE: 0.0360
# Epoch 6/100, Train MSE: 0.0356, Val MSE: 0.0356
# Epoch 7/100, Train MSE: 0.0346, Val MSE: 0.0345
# Epoch 8/100, Train MSE: 0.0340, Val MSE: 0.0337
# Epoch 9/100, Train MSE: 0.0334, Val MSE: 0.0334
# Epoch 10/100, Train MSE: 0.0331, Val MSE: 0.0332
# Epoch 11/100, Train MSE: 0.0329, Val MSE: 0.0330
# Epoch 12/100, Train MSE: 0.0327, Val MSE: 0.0328
# Epoch 13/100, Train MSE: 0.0326, Val MSE: 0.0327
# Epoch 14/100, Train MSE: 0.0324, Val MSE: 0.0326
# Epoch 15/100, Train MSE: 0.0323, Val MSE: 0.0325
# Epoch 16/100, Train MSE: 0.0312, Val MSE: 0.0311
# Epoch 17/100, Train MSE: 0.0308, Val MSE: 0.0310
# Epoch 18/100, Train MSE: 0.0307, Val MSE: 0.0309
# Epoch 19/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 20/100, Train MSE: 0.0305, Val MSE: 0.0307
# Epoch 21/100, Train MSE: 0.0304, Val MSE: 0.0306
# Epoch 22/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 23/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 24/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 25/100, Train MSE: 0.0301, Val MSE: 0.0304
# Epoch 26/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 27/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 28/100, Train MSE: 0.0300, Val MSE: 0.0302
# Epoch 29/100, Train MSE: 0.0299, Val MSE: 0.0302
# Epoch 30/100, Train MSE: 0.0299, Val MSE: 0.0301
# Epoch 31/100, Train MSE: 0.0299, Val MSE: 0.0301
# Epoch 32/100, Train MSE: 0.0298, Val MSE: 0.0300
# Epoch 33/100, Train MSE: 0.0298, Val MSE: 0.0300
# Epoch 34/100, Train MSE: 0.0297, Val MSE: 0.0299
# Epoch 35/100, Train MSE: 0.0297, Val MSE: 0.0299
# Epoch 36/100, Train MSE: 0.0296, Val MSE: 0.0299
# Epoch 37/100, Train MSE: 0.0296, Val MSE: 0.0298
# Epoch 38/100, Train MSE: 0.0296, Val MSE: 0.0298
# Epoch 39/100, Train MSE: 0.0295, Val MSE: 0.0298
# Epoch 40/100, Train MSE: 0.0295, Val MSE: 0.0297
# Epoch 41/100, Train MSE: 0.0295, Val MSE: 0.0297
# Epoch 42/100, Train MSE: 0.0294, Val MSE: 0.0297
# Epoch 43/100, Train MSE: 0.0294, Val MSE: 0.0296
# Epoch 44/100, Train MSE: 0.0294, Val MSE: 0.0296
# Epoch 45/100, Train MSE: 0.0293, Val MSE: 0.0296
# Epoch 46/100, Train MSE: 0.0293, Val MSE: 0.0296
# Epoch 47/100, Train MSE: 0.0293, Val MSE: 0.0295
# Epoch 48/100, Train MSE: 0.0293, Val MSE: 0.0295
# Epoch 49/100, Train MSE: 0.0292, Val MSE: 0.0295
# Epoch 50/100, Train MSE: 0.0292, Val MSE: 0.0295
# Epoch 51/100, Train MSE: 0.0292, Val MSE: 0.0294
# Epoch 52/100, Train MSE: 0.0292, Val MSE: 0.0294
# Epoch 53/100, Train MSE: 0.0291, Val MSE: 0.0294
# Epoch 54/100, Train MSE: 0.0291, Val MSE: 0.0294
# Epoch 55/100, Train MSE: 0.0291, Val MSE: 0.0294
# Epoch 56/100, Train MSE: 0.0291, Val MSE: 0.0293
# Epoch 57/100, Train MSE: 0.0290, Val MSE: 0.0293
# Epoch 58/100, Train MSE: 0.0290, Val MSE: 0.0293
# Epoch 59/100, Train MSE: 0.0290, Val MSE: 0.0293
# Epoch 60/100, Train MSE: 0.0290, Val MSE: 0.0293
# Epoch 61/100, Train MSE: 0.0290, Val MSE: 0.0293
# Epoch 62/100, Train MSE: 0.0290, Val MSE: 0.0292
# Epoch 63/100, Train MSE: 0.0289, Val MSE: 0.0292
# Epoch 64/100, Train MSE: 0.0289, Val MSE: 0.0292
# Epoch 65/100, Train MSE: 0.0289, Val MSE: 0.0292
# Epoch 66/100, Train MSE: 0.0289, Val MSE: 0.0292
# Epoch 67/100, Train MSE: 0.0289, Val MSE: 0.0292
# Epoch 68/100, Train MSE: 0.0289, Val MSE: 0.0291
# Epoch 69/100, Train MSE: 0.0288, Val MSE: 0.0291
# Epoch 70/100, Train MSE: 0.0288, Val MSE: 0.0291
# Epoch 71/100, Train MSE: 0.0288, Val MSE: 0.0291
# Epoch 72/100, Train MSE: 0.0288, Val MSE: 0.0291
# Epoch 73/100, Train MSE: 0.0288, Val MSE: 0.0291
# Epoch 74/100, Train MSE: 0.0288, Val MSE: 0.0291
# Epoch 75/100, Train MSE: 0.0288, Val MSE: 0.0290
# Epoch 76/100, Train MSE: 0.0287, Val MSE: 0.0290
# Epoch 77/100, Train MSE: 0.0287, Val MSE: 0.0290
# Epoch 78/100, Train MSE: 0.0287, Val MSE: 0.0290
# Epoch 79/100, Train MSE: 0.0287, Val MSE: 0.0290
# Epoch 80/100, Train MSE: 0.0287, Val MSE: 0.0290
# Epoch 81/100, Train MSE: 0.0287, Val MSE: 0.0290
# Epoch 82/100, Train MSE: 0.0287, Val MSE: 0.0289
# Epoch 83/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 84/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 85/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 86/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 87/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 88/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 89/100, Train MSE: 0.0286, Val MSE: 0.0289
# Epoch 90/100, Train MSE: 0.0286, Val MSE: 0.0288
# Epoch 91/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 92/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 93/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 94/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 95/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 96/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 97/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 98/100, Train MSE: 0.0285, Val MSE: 0.0288
# Epoch 99/100, Train MSE: 0.0285, Val MSE: 0.0287
# Epoch 100/100, Train MSE: 0.0284, Val MSE: 0.0287

# %%
# انتخاب بهترین وزن‌ها
best_epoch = np.argmin(weights_history_pair2["val_mse"])
w_enc2 = weights_history_pair2["w_enc2"][best_epoch]
b_enc2 = weights_history_pair2["b_enc2"][best_epoch]
w_dec2 = weights_history_pair2["w_dec2"][best_epoch]
b_dec2 = weights_history_pair2["b_dec2"][best_epoch]
print(f"Best weights for Pair 2 selected from epoch {best_epoch + 1} with Val MSE: {weights_history_pair2['val_mse'][best_epoch]:.4f}")
# Out:
# Best weights for Pair 2 selected from epoch 100 with Val MSE: 0.0287

# %%
# محاسبه خروجی‌های Encoder 2 با بهترین وزن‌ها
enc2_outputs_train = np.zeros((num_train, HP.ENC2_SIZE))
enc2_outputs_val = np.zeros((num_val, HP.ENC2_SIZE))
for i in range(num_train):
    enc2_outputs_train[i] = get_activation(np.dot(w_enc2, enc1_outputs_train[i]) + b_enc2, HP.ACT_ENC2)
for i in range(num_val):
    enc2_outputs_val[i] = get_activation(np.dot(w_enc2, enc1_outputs_val[i]) + b_enc2, HP.ACT_ENC2)

# %%
weights_history_pair3 = {
    "w_enc3": [],
    "b_enc3": [],
    "w_dec3": [],
    "b_dec3": [],
    "val_mse": []
}

# %%
# Pair 3: ENC3 + DEC3
for epoch in range(HP.NUM_EPOCHS_PAIR3):
    train_loss = 0
    val_loss = 0
    for i in range(num_train):
        _, _, mse = train_layer_pair(enc2_outputs_train[i], X_train_clean[i], w_enc3, b_enc3, w_dec3, b_dec3, HP.ACT_ENC3, HP.ACT_DEC3, HP.LEARNING_RATE_PAIR3)
        train_loss += mse
    for i in range(num_val):
        out_enc3 = get_activation(np.dot(w_enc3, enc2_outputs_val[i]) + b_enc3, HP.ACT_ENC3)
        out_dec3 = get_activation(np.dot(w_dec3, out_enc3) + b_dec3, HP.ACT_DEC3)
        val_loss += np.mean((X_val_clean[i] - out_dec3) ** 2)
    
    train_mse_history["Pair_3"][epoch] = train_loss / num_train
    val_mse_history["Pair_3"][epoch] = val_loss / num_val
    
    # ذخیره وزن‌ها و خطای اعتبارسنجی
    weights_history_pair3["w_enc3"].append(w_enc3.copy())
    weights_history_pair3["b_enc3"].append(b_enc3.copy())
    weights_history_pair3["w_dec3"].append(w_dec3.copy())
    weights_history_pair3["b_dec3"].append(b_dec3.copy())
    weights_history_pair3["val_mse"].append(val_mse_history["Pair_3"][epoch])
    
    print(f"Epoch {epoch+1}/{HP.NUM_EPOCHS_PAIR3}, Train MSE: {train_mse_history['Pair_3'][epoch]:.4f}, Val MSE: {val_mse_history['Pair_3'][epoch]:.4f}")
# Out:
# Epoch 1/100, Train MSE: 0.0733, Val MSE: 0.0468
# Epoch 2/100, Train MSE: 0.0428, Val MSE: 0.0405
# Epoch 3/100, Train MSE: 0.0390, Val MSE: 0.0379
# Epoch 4/100, Train MSE: 0.0370, Val MSE: 0.0368
# Epoch 5/100, Train MSE: 0.0364, Val MSE: 0.0362
# Epoch 6/100, Train MSE: 0.0357, Val MSE: 0.0356
# Epoch 7/100, Train MSE: 0.0344, Val MSE: 0.0340
# Epoch 8/100, Train MSE: 0.0337, Val MSE: 0.0337
# Epoch 9/100, Train MSE: 0.0335, Val MSE: 0.0336
# Epoch 10/100, Train MSE: 0.0334, Val MSE: 0.0334
# Epoch 11/100, Train MSE: 0.0330, Val MSE: 0.0330
# Epoch 12/100, Train MSE: 0.0328, Val MSE: 0.0328
# Epoch 13/100, Train MSE: 0.0326, Val MSE: 0.0327
# Epoch 14/100, Train MSE: 0.0322, Val MSE: 0.0322
# Epoch 15/100, Train MSE: 0.0321, Val MSE: 0.0322
# Epoch 16/100, Train MSE: 0.0320, Val MSE: 0.0321
# Epoch 17/100, Train MSE: 0.0320, Val MSE: 0.0321
# Epoch 18/100, Train MSE: 0.0319, Val MSE: 0.0321
# Epoch 19/100, Train MSE: 0.0319, Val MSE: 0.0320
# Epoch 20/100, Train MSE: 0.0317, Val MSE: 0.0317
# Epoch 21/100, Train MSE: 0.0315, Val MSE: 0.0317
# Epoch 22/100, Train MSE: 0.0315, Val MSE: 0.0316
# Epoch 23/100, Train MSE: 0.0314, Val MSE: 0.0316
# Epoch 24/100, Train MSE: 0.0314, Val MSE: 0.0315
# Epoch 25/100, Train MSE: 0.0314, Val MSE: 0.0315
# Epoch 26/100, Train MSE: 0.0313, Val MSE: 0.0314
# Epoch 27/100, Train MSE: 0.0313, Val MSE: 0.0314
# Epoch 28/100, Train MSE: 0.0312, Val MSE: 0.0313
# Epoch 29/100, Train MSE: 0.0311, Val MSE: 0.0313
# Epoch 30/100, Train MSE: 0.0311, Val MSE: 0.0312
# Epoch 31/100, Train MSE: 0.0310, Val MSE: 0.0312
# Epoch 32/100, Train MSE: 0.0310, Val MSE: 0.0311
# Epoch 33/100, Train MSE: 0.0309, Val MSE: 0.0311
# Epoch 34/100, Train MSE: 0.0309, Val MSE: 0.0310
# Epoch 35/100, Train MSE: 0.0308, Val MSE: 0.0310
# Epoch 36/100, Train MSE: 0.0308, Val MSE: 0.0310
# Epoch 37/100, Train MSE: 0.0308, Val MSE: 0.0310
# Epoch 38/100, Train MSE: 0.0308, Val MSE: 0.0310
# Epoch 39/100, Train MSE: 0.0308, Val MSE: 0.0310
# Epoch 40/100, Train MSE: 0.0307, Val MSE: 0.0310
# Epoch 41/100, Train MSE: 0.0307, Val MSE: 0.0309
# Epoch 42/100, Train MSE: 0.0307, Val MSE: 0.0309
# Epoch 43/100, Train MSE: 0.0307, Val MSE: 0.0309
# Epoch 44/100, Train MSE: 0.0307, Val MSE: 0.0309
# Epoch 45/100, Train MSE: 0.0307, Val MSE: 0.0309
# Epoch 46/100, Train MSE: 0.0306, Val MSE: 0.0309
# Epoch 47/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 48/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 49/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 50/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 51/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 52/100, Train MSE: 0.0306, Val MSE: 0.0308
# Epoch 53/100, Train MSE: 0.0306, Val MSE: 0.0307
# Epoch 54/100, Train MSE: 0.0305, Val MSE: 0.0307
# Epoch 55/100, Train MSE: 0.0305, Val MSE: 0.0307
# Epoch 56/100, Train MSE: 0.0305, Val MSE: 0.0307
# Epoch 57/100, Train MSE: 0.0305, Val MSE: 0.0306
# Epoch 58/100, Train MSE: 0.0304, Val MSE: 0.0306
# Epoch 59/100, Train MSE: 0.0304, Val MSE: 0.0306
# Epoch 60/100, Train MSE: 0.0304, Val MSE: 0.0305
# Epoch 61/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 62/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 63/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 64/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 65/100, Train MSE: 0.0303, Val MSE: 0.0305
# Epoch 66/100, Train MSE: 0.0303, Val MSE: 0.0304
# Epoch 67/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 68/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 69/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 70/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 71/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 72/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 73/100, Train MSE: 0.0302, Val MSE: 0.0304
# Epoch 74/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 75/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 76/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 77/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 78/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 79/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 80/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 81/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 82/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 83/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 84/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 85/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 86/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 87/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 88/100, Train MSE: 0.0301, Val MSE: 0.0303
# Epoch 89/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 90/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 91/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 92/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 93/100, Train MSE: 0.0300, Val MSE: 0.0302
# Epoch 94/100, Train MSE: 0.0300, Val MSE: 0.0302
# Epoch 95/100, Train MSE: 0.0300, Val MSE: 0.0302
# Epoch 96/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 97/100, Train MSE: 0.0300, Val MSE: 0.0303
# Epoch 98/100, Train MSE: 0.0300, Val MSE: 0.0302
# Epoch 99/100, Train MSE: 0.0300, Val MSE: 0.0302
# Epoch 100/100, Train MSE: 0.0300, Val MSE: 0.0302

# %%
# انتخاب بهترین وزن‌ها
best_epoch = np.argmin(weights_history_pair3["val_mse"])
w_enc3 = weights_history_pair3["w_enc3"][best_epoch]
b_enc3 = weights_history_pair3["b_enc3"][best_epoch]
w_dec3 = weights_history_pair3["w_dec3"][best_epoch]
b_dec3 = weights_history_pair3["b_dec3"][best_epoch]
print(f"Best weights for Pair 3 selected from epoch {best_epoch + 1} with Val MSE: {weights_history_pair3['val_mse'][best_epoch]:.4f}")
# Out:
# Best weights for Pair 3 selected from epoch 99 with Val MSE: 0.0302

# %%
# محاسبه خروجی‌های Bottleneck با بهترین وزن‌ها
bottleneck_outputs_train = np.zeros((num_train, HP.BOTTLENECK_SIZE))
bottleneck_outputs_val = np.zeros((num_val, HP.BOTTLENECK_SIZE))
for i in range(num_train):
    bottleneck_outputs_train[i] = get_activation(np.dot(w_enc3, enc2_outputs_train[i]) + b_enc3, HP.ACT_ENC3)
for i in range(num_val):
    bottleneck_outputs_val[i] = get_activation(np.dot(w_enc3, enc2_outputs_val[i]) + b_enc3, HP.ACT_ENC3)

# %% [markdown]
# ### MLP

# %%
weights_history_mlp = {
    "w_mlp1": [],
    "b_mlp1": [],
    "w_mlp2": [],
    "b_mlp2": [],
    "val_acc": []
}

# %%
# Training MLP
for epoch in range(HP.NUM_EPOCHS_MLP):
    train_loss = 0
    train_correct = 0
    for i in range(num_train):
        bottleneck = full_feedforward_encoder(X_train_noisy[i])
        out_mlp2 = train_mlp(bottleneck, y_train[i], HP.LEARNING_RATE_MLP)
        train_loss += -np.sum(y_train[i] * np.log(out_mlp2 + 1e-10))  # Cross-entropy loss
        if np.argmax(out_mlp2) == np.argmax(y_train[i]):
            train_correct += 1
    
    val_loss = 0
    val_correct = 0
    for i in range(num_val):
        bottleneck = full_feedforward_encoder(X_val_noisy[i])
        net_mlp1 = np.dot(w_mlp1, bottleneck) + b_mlp1
        out_mlp1 = get_activation(net_mlp1, HP.ACT_MLP1)
        net_mlp2 = np.dot(w_mlp2, out_mlp1) + b_mlp2
        out_mlp2 = get_activation(net_mlp2, HP.ACT_MLP2)
        val_loss += -np.sum(y_val[i] * np.log(out_mlp2 + 1e-10))  # Cross-entropy loss
        if np.argmax(out_mlp2) == np.argmax(y_val[i]):
            val_correct += 1
    
    train_acc_history[epoch] = train_correct / num_train
    val_acc_history[epoch] = val_correct / num_val
    
    # ذخیره وزن‌ها و دقت اعتبارسنجی
    weights_history_mlp["w_mlp1"].append(w_mlp1.copy())
    weights_history_mlp["b_mlp1"].append(b_mlp1.copy())
    weights_history_mlp["w_mlp2"].append(w_mlp2.copy())
    weights_history_mlp["b_mlp2"].append(b_mlp2.copy())
    weights_history_mlp["val_acc"].append(val_acc_history[epoch])
    
    print(f"Epoch {epoch+1}/{HP.NUM_EPOCHS_MLP}, Train Acc: {train_acc_history[epoch]:.4f}, Val Acc: {val_acc_history[epoch]:.4f}")
# Out:
# Epoch 1/500, Train Acc: 0.7882, Val Acc: 0.8206
# Epoch 2/500, Train Acc: 0.8403, Val Acc: 0.8351
# Epoch 3/500, Train Acc: 0.8510, Val Acc: 0.8409
# Epoch 4/500, Train Acc: 0.8576, Val Acc: 0.8447
# Epoch 5/500, Train Acc: 0.8629, Val Acc: 0.8471
# Epoch 6/500, Train Acc: 0.8658, Val Acc: 0.8487
# Epoch 7/500, Train Acc: 0.8678, Val Acc: 0.8509
# Epoch 8/500, Train Acc: 0.8690, Val Acc: 0.8533
# Epoch 9/500, Train Acc: 0.8705, Val Acc: 0.8564
# Epoch 10/500, Train Acc: 0.8723, Val Acc: 0.8563
# Epoch 11/500, Train Acc: 0.8732, Val Acc: 0.8573
# Epoch 12/500, Train Acc: 0.8739, Val Acc: 0.8579
# Epoch 13/500, Train Acc: 0.8750, Val Acc: 0.8579
# Epoch 14/500, Train Acc: 0.8757, Val Acc: 0.8591
# Epoch 15/500, Train Acc: 0.8772, Val Acc: 0.8589
# Epoch 16/500, Train Acc: 0.8774, Val Acc: 0.8611
# Epoch 17/500, Train Acc: 0.8780, Val Acc: 0.8604
# Epoch 18/500, Train Acc: 0.8785, Val Acc: 0.8597
# Epoch 19/500, Train Acc: 0.8791, Val Acc: 0.8594
# Epoch 20/500, Train Acc: 0.8793, Val Acc: 0.8596
# Epoch 21/500, Train Acc: 0.8797, Val Acc: 0.8620
# Epoch 22/500, Train Acc: 0.8807, Val Acc: 0.8616
# Epoch 23/500, Train Acc: 0.8811, Val Acc: 0.8613
# Epoch 24/500, Train Acc: 0.8814, Val Acc: 0.8621
# Epoch 25/500, Train Acc: 0.8822, Val Acc: 0.8616
# Epoch 26/500, Train Acc: 0.8824, Val Acc: 0.8619
# Epoch 27/500, Train Acc: 0.8831, Val Acc: 0.8627
# Epoch 28/500, Train Acc: 0.8837, Val Acc: 0.8633
# Epoch 29/500, Train Acc: 0.8837, Val Acc: 0.8644
# Epoch 30/500, Train Acc: 0.8847, Val Acc: 0.8646
# Epoch 31/500, Train Acc: 0.8848, Val Acc: 0.8653
# Epoch 32/500, Train Acc: 0.8851, Val Acc: 0.8656
# Epoch 33/500, Train Acc: 0.8861, Val Acc: 0.8664
# Epoch 34/500, Train Acc: 0.8862, Val Acc: 0.8664
# Epoch 35/500, Train Acc: 0.8864, Val Acc: 0.8656
# Epoch 36/500, Train Acc: 0.8866, Val Acc: 0.8661
# Epoch 37/500, Train Acc: 0.8871, Val Acc: 0.8663
# Epoch 38/500, Train Acc: 0.8876, Val Acc: 0.8664
# Epoch 39/500, Train Acc: 0.8877, Val Acc: 0.8664
# Epoch 40/500, Train Acc: 0.8879, Val Acc: 0.8671
# Epoch 41/500, Train Acc: 0.8882, Val Acc: 0.8670
# Epoch 42/500, Train Acc: 0.8887, Val Acc: 0.8664
# Epoch 43/500, Train Acc: 0.8887, Val Acc: 0.8663
# Epoch 44/500, Train Acc: 0.8890, Val Acc: 0.8666
# Epoch 45/500, Train Acc: 0.8886, Val Acc: 0.8664
# Epoch 46/500, Train Acc: 0.8893, Val Acc: 0.8664
# Epoch 47/500, Train Acc: 0.8890, Val Acc: 0.8670
# Epoch 48/500, Train Acc: 0.8894, Val Acc: 0.8657
# Epoch 49/500, Train Acc: 0.8895, Val Acc: 0.8660
# Epoch 50/500, Train Acc: 0.8892, Val Acc: 0.8670
# Epoch 51/500, Train Acc: 0.8897, Val Acc: 0.8659
# Epoch 52/500, Train Acc: 0.8897, Val Acc: 0.8663
# Epoch 53/500, Train Acc: 0.8898, Val Acc: 0.8660
# Epoch 54/500, Train Acc: 0.8901, Val Acc: 0.8667
# Epoch 55/500, Train Acc: 0.8898, Val Acc: 0.8669
# Epoch 56/500, Train Acc: 0.8900, Val Acc: 0.8664
# Epoch 57/500, Train Acc: 0.8902, Val Acc: 0.8673
# Epoch 58/500, Train Acc: 0.8904, Val Acc: 0.8677
# Epoch 59/500, Train Acc: 0.8907, Val Acc: 0.8686
# Epoch 60/500, Train Acc: 0.8908, Val Acc: 0.8684
# Epoch 61/500, Train Acc: 0.8909, Val Acc: 0.8681
# Epoch 62/500, Train Acc: 0.8907, Val Acc: 0.8677
# Epoch 63/500, Train Acc: 0.8911, Val Acc: 0.8690
# Epoch 64/500, Train Acc: 0.8911, Val Acc: 0.8684
# Epoch 65/500, Train Acc: 0.8912, Val Acc: 0.8687
# Epoch 66/500, Train Acc: 0.8911, Val Acc: 0.8690
# Epoch 67/500, Train Acc: 0.8915, Val Acc: 0.8691
# Epoch 68/500, Train Acc: 0.8916, Val Acc: 0.8683
# Epoch 69/500, Train Acc: 0.8914, Val Acc: 0.8697
# Epoch 70/500, Train Acc: 0.8916, Val Acc: 0.8690
# Epoch 71/500, Train Acc: 0.8919, Val Acc: 0.8699
# Epoch 72/500, Train Acc: 0.8915, Val Acc: 0.8693
# Epoch 73/500, Train Acc: 0.8919, Val Acc: 0.8686
# Epoch 74/500, Train Acc: 0.8920, Val Acc: 0.8691
# Epoch 75/500, Train Acc: 0.8919, Val Acc: 0.8681
# Epoch 76/500, Train Acc: 0.8918, Val Acc: 0.8689
# Epoch 77/500, Train Acc: 0.8915, Val Acc: 0.8684
# Epoch 78/500, Train Acc: 0.8922, Val Acc: 0.8689
# Epoch 79/500, Train Acc: 0.8919, Val Acc: 0.8694
# Epoch 80/500, Train Acc: 0.8918, Val Acc: 0.8694
# Epoch 81/500, Train Acc: 0.8921, Val Acc: 0.8693
# Epoch 82/500, Train Acc: 0.8921, Val Acc: 0.8696
# Epoch 83/500, Train Acc: 0.8920, Val Acc: 0.8696
# Epoch 84/500, Train Acc: 0.8921, Val Acc: 0.8694
# Epoch 85/500, Train Acc: 0.8919, Val Acc: 0.8706
# Epoch 86/500, Train Acc: 0.8919, Val Acc: 0.8707
# Epoch 87/500, Train Acc: 0.8917, Val Acc: 0.8700
# Epoch 88/500, Train Acc: 0.8922, Val Acc: 0.8709
# Epoch 89/500, Train Acc: 0.8921, Val Acc: 0.8706
# Epoch 90/500, Train Acc: 0.8926, Val Acc: 0.8704
# Epoch 91/500, Train Acc: 0.8929, Val Acc: 0.8710
# Epoch 92/500, Train Acc: 0.8933, Val Acc: 0.8710
# Epoch 93/500, Train Acc: 0.8928, Val Acc: 0.8706
# Epoch 94/500, Train Acc: 0.8930, Val Acc: 0.8716
# Epoch 95/500, Train Acc: 0.8933, Val Acc: 0.8710
# Epoch 96/500, Train Acc: 0.8931, Val Acc: 0.8711
# Epoch 97/500, Train Acc: 0.8935, Val Acc: 0.8717
# Epoch 98/500, Train Acc: 0.8934, Val Acc: 0.8716
# Epoch 99/500, Train Acc: 0.8933, Val Acc: 0.8714
# Epoch 100/500, Train Acc: 0.8932, Val Acc: 0.8717
# Epoch 101/500, Train Acc: 0.8936, Val Acc: 0.8717
# Epoch 102/500, Train Acc: 0.8939, Val Acc: 0.8709
# Epoch 103/500, Train Acc: 0.8940, Val Acc: 0.8717
# Epoch 104/500, Train Acc: 0.8939, Val Acc: 0.8717
# Epoch 105/500, Train Acc: 0.8945, Val Acc: 0.8714
# Epoch 106/500, Train Acc: 0.8944, Val Acc: 0.8716
# Epoch 107/500, Train Acc: 0.8943, Val Acc: 0.8707
# Epoch 108/500, Train Acc: 0.8942, Val Acc: 0.8700
# Epoch 109/500, Train Acc: 0.8945, Val Acc: 0.8710
# Epoch 110/500, Train Acc: 0.8942, Val Acc: 0.8701
# Epoch 111/500, Train Acc: 0.8941, Val Acc: 0.8704
# Epoch 112/500, Train Acc: 0.8941, Val Acc: 0.8714
# Epoch 113/500, Train Acc: 0.8940, Val Acc: 0.8704
# Epoch 114/500, Train Acc: 0.8941, Val Acc: 0.8703
# Epoch 115/500, Train Acc: 0.8942, Val Acc: 0.8701
# Epoch 116/500, Train Acc: 0.8940, Val Acc: 0.8697
# Epoch 117/500, Train Acc: 0.8946, Val Acc: 0.8689
# Epoch 118/500, Train Acc: 0.8943, Val Acc: 0.8697
# Epoch 119/500, Train Acc: 0.8939, Val Acc: 0.8694
# Epoch 120/500, Train Acc: 0.8942, Val Acc: 0.8701
# Epoch 121/500, Train Acc: 0.8942, Val Acc: 0.8700
# Epoch 122/500, Train Acc: 0.8944, Val Acc: 0.8696
# Epoch 123/500, Train Acc: 0.8947, Val Acc: 0.8706
# Epoch 124/500, Train Acc: 0.8946, Val Acc: 0.8697
# Epoch 125/500, Train Acc: 0.8947, Val Acc: 0.8707
# Epoch 126/500, Train Acc: 0.8945, Val Acc: 0.8700
# Epoch 127/500, Train Acc: 0.8947, Val Acc: 0.8684
# Epoch 128/500, Train Acc: 0.8947, Val Acc: 0.8696
# Epoch 129/500, Train Acc: 0.8948, Val Acc: 0.8694
# Epoch 130/500, Train Acc: 0.8950, Val Acc: 0.8703
# Epoch 131/500, Train Acc: 0.8948, Val Acc: 0.8696
# Epoch 132/500, Train Acc: 0.8950, Val Acc: 0.8690
# Epoch 133/500, Train Acc: 0.8951, Val Acc: 0.8706
# Epoch 134/500, Train Acc: 0.8950, Val Acc: 0.8706
# Epoch 135/500, Train Acc: 0.8958, Val Acc: 0.8706
# Epoch 136/500, Train Acc: 0.8954, Val Acc: 0.8704
# Epoch 137/500, Train Acc: 0.8954, Val Acc: 0.8704
# Epoch 138/500, Train Acc: 0.8957, Val Acc: 0.8697
# Epoch 139/500, Train Acc: 0.8957, Val Acc: 0.8697
# Epoch 140/500, Train Acc: 0.8961, Val Acc: 0.8701
# Epoch 141/500, Train Acc: 0.8958, Val Acc: 0.8691
# Epoch 142/500, Train Acc: 0.8955, Val Acc: 0.8687
# Epoch 143/500, Train Acc: 0.8959, Val Acc: 0.8699
# Epoch 144/500, Train Acc: 0.8959, Val Acc: 0.8703
# Epoch 145/500, Train Acc: 0.8959, Val Acc: 0.8699
# Epoch 146/500, Train Acc: 0.8960, Val Acc: 0.8703
# Epoch 147/500, Train Acc: 0.8957, Val Acc: 0.8697
# Epoch 148/500, Train Acc: 0.8958, Val Acc: 0.8706
# Epoch 149/500, Train Acc: 0.8958, Val Acc: 0.8704
# Epoch 150/500, Train Acc: 0.8962, Val Acc: 0.8694
# Epoch 151/500, Train Acc: 0.8963, Val Acc: 0.8697
# Epoch 152/500, Train Acc: 0.8960, Val Acc: 0.8689
# Epoch 153/500, Train Acc: 0.8964, Val Acc: 0.8691
# Epoch 154/500, Train Acc: 0.8964, Val Acc: 0.8683
# Epoch 155/500, Train Acc: 0.8966, Val Acc: 0.8679
# Epoch 156/500, Train Acc: 0.8966, Val Acc: 0.8686
# Epoch 157/500, Train Acc: 0.8967, Val Acc: 0.8684
# Epoch 158/500, Train Acc: 0.8971, Val Acc: 0.8680
# Epoch 159/500, Train Acc: 0.8974, Val Acc: 0.8680
# Epoch 160/500, Train Acc: 0.8970, Val Acc: 0.8673
# Epoch 161/500, Train Acc: 0.8973, Val Acc: 0.8674
# Epoch 162/500, Train Acc: 0.8969, Val Acc: 0.8677
# Epoch 163/500, Train Acc: 0.8970, Val Acc: 0.8676
# Epoch 164/500, Train Acc: 0.8971, Val Acc: 0.8684
# Epoch 165/500, Train Acc: 0.8975, Val Acc: 0.8683
# Epoch 166/500, Train Acc: 0.8975, Val Acc: 0.8679
# Epoch 167/500, Train Acc: 0.8972, Val Acc: 0.8679
# Epoch 168/500, Train Acc: 0.8968, Val Acc: 0.8683
# Epoch 169/500, Train Acc: 0.8971, Val Acc: 0.8681
# Epoch 170/500, Train Acc: 0.8973, Val Acc: 0.8679
# Epoch 171/500, Train Acc: 0.8973, Val Acc: 0.8683
# Epoch 172/500, Train Acc: 0.8968, Val Acc: 0.8696
# Epoch 173/500, Train Acc: 0.8973, Val Acc: 0.8689
# Epoch 174/500, Train Acc: 0.8977, Val Acc: 0.8690
# Epoch 175/500, Train Acc: 0.8975, Val Acc: 0.8691
# Epoch 176/500, Train Acc: 0.8972, Val Acc: 0.8683
# Epoch 177/500, Train Acc: 0.8975, Val Acc: 0.8684
# Epoch 178/500, Train Acc: 0.8974, Val Acc: 0.8687
# Epoch 179/500, Train Acc: 0.8977, Val Acc: 0.8681
# Epoch 180/500, Train Acc: 0.8972, Val Acc: 0.8686
# Epoch 181/500, Train Acc: 0.8974, Val Acc: 0.8674
# Epoch 182/500, Train Acc: 0.8977, Val Acc: 0.8680
# Epoch 183/500, Train Acc: 0.8982, Val Acc: 0.8680
# Epoch 184/500, Train Acc: 0.8978, Val Acc: 0.8679
# Epoch 185/500, Train Acc: 0.8977, Val Acc: 0.8686
# Epoch 186/500, Train Acc: 0.8975, Val Acc: 0.8677
# Epoch 187/500, Train Acc: 0.8976, Val Acc: 0.8683
# Epoch 188/500, Train Acc: 0.8978, Val Acc: 0.8677
# Epoch 189/500, Train Acc: 0.8971, Val Acc: 0.8680
# Epoch 190/500, Train Acc: 0.8975, Val Acc: 0.8677
# Epoch 191/500, Train Acc: 0.8977, Val Acc: 0.8671
# Epoch 192/500, Train Acc: 0.8980, Val Acc: 0.8681
# Epoch 193/500, Train Acc: 0.8979, Val Acc: 0.8683
# Epoch 194/500, Train Acc: 0.8978, Val Acc: 0.8676
# Epoch 195/500, Train Acc: 0.8978, Val Acc: 0.8669
# Epoch 196/500, Train Acc: 0.8976, Val Acc: 0.8673
# Epoch 197/500, Train Acc: 0.8976, Val Acc: 0.8673
# Epoch 198/500, Train Acc: 0.8979, Val Acc: 0.8677
# Epoch 199/500, Train Acc: 0.8972, Val Acc: 0.8669
# Epoch 200/500, Train Acc: 0.8974, Val Acc: 0.8676
# Epoch 201/500, Train Acc: 0.8976, Val Acc: 0.8676
# Epoch 202/500, Train Acc: 0.8977, Val Acc: 0.8677
# Epoch 203/500, Train Acc: 0.8976, Val Acc: 0.8690
# Epoch 204/500, Train Acc: 0.8972, Val Acc: 0.8683
# Epoch 205/500, Train Acc: 0.8977, Val Acc: 0.8686
# Epoch 206/500, Train Acc: 0.8977, Val Acc: 0.8676
# Epoch 207/500, Train Acc: 0.8979, Val Acc: 0.8673
# Epoch 208/500, Train Acc: 0.8976, Val Acc: 0.8674
# Epoch 209/500, Train Acc: 0.8977, Val Acc: 0.8670
# Epoch 210/500, Train Acc: 0.8974, Val Acc: 0.8680
# Epoch 211/500, Train Acc: 0.8976, Val Acc: 0.8676
# Epoch 212/500, Train Acc: 0.8976, Val Acc: 0.8669
# Epoch 213/500, Train Acc: 0.8979, Val Acc: 0.8677
# Epoch 214/500, Train Acc: 0.8979, Val Acc: 0.8670
# Epoch 215/500, Train Acc: 0.8979, Val Acc: 0.8679
# Epoch 216/500, Train Acc: 0.8978, Val Acc: 0.8676
# Epoch 217/500, Train Acc: 0.8977, Val Acc: 0.8683
# Epoch 218/500, Train Acc: 0.8979, Val Acc: 0.8680
# Epoch 219/500, Train Acc: 0.8982, Val Acc: 0.8677
# Epoch 220/500, Train Acc: 0.8979, Val Acc: 0.8679
# Epoch 221/500, Train Acc: 0.8979, Val Acc: 0.8686
# Epoch 222/500, Train Acc: 0.8979, Val Acc: 0.8681
# Epoch 223/500, Train Acc: 0.8984, Val Acc: 0.8687
# Epoch 224/500, Train Acc: 0.8982, Val Acc: 0.8684
# Epoch 225/500, Train Acc: 0.8982, Val Acc: 0.8674
# Epoch 226/500, Train Acc: 0.8977, Val Acc: 0.8690
# Epoch 227/500, Train Acc: 0.8983, Val Acc: 0.8693
# Epoch 228/500, Train Acc: 0.8980, Val Acc: 0.8691
# Epoch 229/500, Train Acc: 0.8981, Val Acc: 0.8696
# Epoch 230/500, Train Acc: 0.8982, Val Acc: 0.8687
# Epoch 231/500, Train Acc: 0.8981, Val Acc: 0.8693
# Epoch 232/500, Train Acc: 0.8983, Val Acc: 0.8691
# Epoch 233/500, Train Acc: 0.8978, Val Acc: 0.8700
# Epoch 234/500, Train Acc: 0.8980, Val Acc: 0.8699
# Epoch 235/500, Train Acc: 0.8981, Val Acc: 0.8693
# Epoch 236/500, Train Acc: 0.8984, Val Acc: 0.8697
# Epoch 237/500, Train Acc: 0.8981, Val Acc: 0.8697
# Epoch 238/500, Train Acc: 0.8981, Val Acc: 0.8699
# Epoch 239/500, Train Acc: 0.8980, Val Acc: 0.8693
# Epoch 240/500, Train Acc: 0.8981, Val Acc: 0.8693
# Epoch 241/500, Train Acc: 0.8981, Val Acc: 0.8683
# Epoch 242/500, Train Acc: 0.8977, Val Acc: 0.8697
# Epoch 243/500, Train Acc: 0.8982, Val Acc: 0.8691
# Epoch 244/500, Train Acc: 0.8978, Val Acc: 0.8694
# Epoch 245/500, Train Acc: 0.8983, Val Acc: 0.8697
# Epoch 246/500, Train Acc: 0.8980, Val Acc: 0.8679
# Epoch 247/500, Train Acc: 0.8981, Val Acc: 0.8696
# Epoch 248/500, Train Acc: 0.8983, Val Acc: 0.8684
# Epoch 249/500, Train Acc: 0.8978, Val Acc: 0.8686
# Epoch 250/500, Train Acc: 0.8982, Val Acc: 0.8676
# Epoch 251/500, Train Acc: 0.8982, Val Acc: 0.8686
# Epoch 252/500, Train Acc: 0.8982, Val Acc: 0.8681
# Epoch 253/500, Train Acc: 0.8983, Val Acc: 0.8684
# Epoch 254/500, Train Acc: 0.8980, Val Acc: 0.8677
# Epoch 255/500, Train Acc: 0.8985, Val Acc: 0.8683
# Epoch 256/500, Train Acc: 0.8981, Val Acc: 0.8669
# Epoch 257/500, Train Acc: 0.8987, Val Acc: 0.8684
# Epoch 258/500, Train Acc: 0.8987, Val Acc: 0.8689
# Epoch 259/500, Train Acc: 0.8985, Val Acc: 0.8680
# Epoch 260/500, Train Acc: 0.8983, Val Acc: 0.8683
# Epoch 261/500, Train Acc: 0.8984, Val Acc: 0.8690
# Epoch 262/500, Train Acc: 0.8984, Val Acc: 0.8686
# Epoch 263/500, Train Acc: 0.8982, Val Acc: 0.8687
# Epoch 264/500, Train Acc: 0.8985, Val Acc: 0.8681
# Epoch 265/500, Train Acc: 0.8984, Val Acc: 0.8686
# Epoch 266/500, Train Acc: 0.8982, Val Acc: 0.8684
# Epoch 267/500, Train Acc: 0.8984, Val Acc: 0.8683
# Epoch 268/500, Train Acc: 0.8986, Val Acc: 0.8686
# Epoch 269/500, Train Acc: 0.8983, Val Acc: 0.8679
# Epoch 270/500, Train Acc: 0.8984, Val Acc: 0.8686
# Epoch 271/500, Train Acc: 0.8986, Val Acc: 0.8686
# Epoch 272/500, Train Acc: 0.8983, Val Acc: 0.8686
# Epoch 273/500, Train Acc: 0.8984, Val Acc: 0.8683
# Epoch 274/500, Train Acc: 0.8986, Val Acc: 0.8690
# Epoch 275/500, Train Acc: 0.8986, Val Acc: 0.8680
# Epoch 276/500, Train Acc: 0.8985, Val Acc: 0.8684
# Epoch 277/500, Train Acc: 0.8986, Val Acc: 0.8691
# Epoch 278/500, Train Acc: 0.8987, Val Acc: 0.8676
# Epoch 279/500, Train Acc: 0.8983, Val Acc: 0.8683
# Epoch 280/500, Train Acc: 0.8987, Val Acc: 0.8686
# Epoch 281/500, Train Acc: 0.8984, Val Acc: 0.8684
# Epoch 282/500, Train Acc: 0.8988, Val Acc: 0.8680
# Epoch 283/500, Train Acc: 0.8987, Val Acc: 0.8676
# Epoch 284/500, Train Acc: 0.8988, Val Acc: 0.8686
# Epoch 285/500, Train Acc: 0.8992, Val Acc: 0.8677
# Epoch 286/500, Train Acc: 0.8992, Val Acc: 0.8684
# Epoch 287/500, Train Acc: 0.8989, Val Acc: 0.8679
# Epoch 288/500, Train Acc: 0.8989, Val Acc: 0.8681
# Epoch 289/500, Train Acc: 0.8985, Val Acc: 0.8677
# Epoch 290/500, Train Acc: 0.8990, Val Acc: 0.8680
# Epoch 291/500, Train Acc: 0.8992, Val Acc: 0.8676
# Epoch 292/500, Train Acc: 0.8985, Val Acc: 0.8683
# Epoch 293/500, Train Acc: 0.8990, Val Acc: 0.8683
# Epoch 294/500, Train Acc: 0.8988, Val Acc: 0.8684
# Epoch 295/500, Train Acc: 0.8988, Val Acc: 0.8670
# Epoch 296/500, Train Acc: 0.8991, Val Acc: 0.8669
# Epoch 297/500, Train Acc: 0.8989, Val Acc: 0.8680
# Epoch 298/500, Train Acc: 0.8991, Val Acc: 0.8667
# Epoch 299/500, Train Acc: 0.8988, Val Acc: 0.8684
# Epoch 300/500, Train Acc: 0.8992, Val Acc: 0.8670
# Epoch 301/500, Train Acc: 0.8992, Val Acc: 0.8674
# Epoch 302/500, Train Acc: 0.8988, Val Acc: 0.8686
# Epoch 303/500, Train Acc: 0.8991, Val Acc: 0.8663
# Epoch 304/500, Train Acc: 0.8991, Val Acc: 0.8677
# Epoch 305/500, Train Acc: 0.8994, Val Acc: 0.8667
# Epoch 306/500, Train Acc: 0.8990, Val Acc: 0.8666
# Epoch 307/500, Train Acc: 0.8993, Val Acc: 0.8670
# Epoch 308/500, Train Acc: 0.8990, Val Acc: 0.8669
# Epoch 309/500, Train Acc: 0.8994, Val Acc: 0.8661
# Epoch 310/500, Train Acc: 0.8992, Val Acc: 0.8667
# Epoch 311/500, Train Acc: 0.8992, Val Acc: 0.8661
# Epoch 312/500, Train Acc: 0.8990, Val Acc: 0.8669
# Epoch 313/500, Train Acc: 0.8992, Val Acc: 0.8664
# Epoch 314/500, Train Acc: 0.8993, Val Acc: 0.8664
# Epoch 315/500, Train Acc: 0.8995, Val Acc: 0.8664
# Epoch 316/500, Train Acc: 0.8997, Val Acc: 0.8667
# Epoch 317/500, Train Acc: 0.8996, Val Acc: 0.8669
# Epoch 318/500, Train Acc: 0.8997, Val Acc: 0.8666
# Epoch 319/500, Train Acc: 0.8998, Val Acc: 0.8657
# Epoch 320/500, Train Acc: 0.8997, Val Acc: 0.8656
# Epoch 321/500, Train Acc: 0.8996, Val Acc: 0.8661
# Epoch 322/500, Train Acc: 0.8998, Val Acc: 0.8660
# Epoch 323/500, Train Acc: 0.8997, Val Acc: 0.8651
# Epoch 324/500, Train Acc: 0.8997, Val Acc: 0.8667
# Epoch 325/500, Train Acc: 0.8998, Val Acc: 0.8664
# Epoch 326/500, Train Acc: 0.8995, Val Acc: 0.8661
# Epoch 327/500, Train Acc: 0.8994, Val Acc: 0.8664
# Epoch 328/500, Train Acc: 0.8998, Val Acc: 0.8666
# Epoch 329/500, Train Acc: 0.8994, Val Acc: 0.8667
# Epoch 330/500, Train Acc: 0.8994, Val Acc: 0.8657
# Epoch 331/500, Train Acc: 0.8997, Val Acc: 0.8659
# Epoch 332/500, Train Acc: 0.8995, Val Acc: 0.8669
# Epoch 333/500, Train Acc: 0.8996, Val Acc: 0.8669
# Epoch 334/500, Train Acc: 0.8997, Val Acc: 0.8657
# Epoch 335/500, Train Acc: 0.8999, Val Acc: 0.8667
# Epoch 336/500, Train Acc: 0.8996, Val Acc: 0.8669
# Epoch 337/500, Train Acc: 0.9001, Val Acc: 0.8674
# Epoch 338/500, Train Acc: 0.8998, Val Acc: 0.8663
# Epoch 339/500, Train Acc: 0.8999, Val Acc: 0.8670
# Epoch 340/500, Train Acc: 0.9002, Val Acc: 0.8669
# Epoch 341/500, Train Acc: 0.8999, Val Acc: 0.8661
# Epoch 342/500, Train Acc: 0.9000, Val Acc: 0.8666
# Epoch 343/500, Train Acc: 0.8997, Val Acc: 0.8663
# Epoch 344/500, Train Acc: 0.9001, Val Acc: 0.8667
# Epoch 345/500, Train Acc: 0.8999, Val Acc: 0.8664
# Epoch 346/500, Train Acc: 0.9001, Val Acc: 0.8667
# Epoch 347/500, Train Acc: 0.8999, Val Acc: 0.8667
# Epoch 348/500, Train Acc: 0.9001, Val Acc: 0.8667
# Epoch 349/500, Train Acc: 0.8999, Val Acc: 0.8669
# Epoch 350/500, Train Acc: 0.9003, Val Acc: 0.8674
# Epoch 351/500, Train Acc: 0.8999, Val Acc: 0.8667
# Epoch 352/500, Train Acc: 0.9001, Val Acc: 0.8673
# Epoch 353/500, Train Acc: 0.8998, Val Acc: 0.8674
# Epoch 354/500, Train Acc: 0.8998, Val Acc: 0.8677
# Epoch 355/500, Train Acc: 0.9002, Val Acc: 0.8680
# Epoch 356/500, Train Acc: 0.8999, Val Acc: 0.8674
# Epoch 357/500, Train Acc: 0.9004, Val Acc: 0.8673
# Epoch 358/500, Train Acc: 0.8999, Val Acc: 0.8679
# Epoch 359/500, Train Acc: 0.9004, Val Acc: 0.8674
# Epoch 360/500, Train Acc: 0.9001, Val Acc: 0.8686
# Epoch 361/500, Train Acc: 0.9003, Val Acc: 0.8674
# Epoch 362/500, Train Acc: 0.9003, Val Acc: 0.8677
# Epoch 363/500, Train Acc: 0.9003, Val Acc: 0.8677
# Epoch 364/500, Train Acc: 0.9002, Val Acc: 0.8680
# Epoch 365/500, Train Acc: 0.9002, Val Acc: 0.8671
# Epoch 366/500, Train Acc: 0.9004, Val Acc: 0.8684
# Epoch 367/500, Train Acc: 0.9004, Val Acc: 0.8684
# Epoch 368/500, Train Acc: 0.9001, Val Acc: 0.8679
# Epoch 369/500, Train Acc: 0.9003, Val Acc: 0.8680
# Epoch 370/500, Train Acc: 0.9002, Val Acc: 0.8679
# Epoch 371/500, Train Acc: 0.9001, Val Acc: 0.8680
# Epoch 372/500, Train Acc: 0.9004, Val Acc: 0.8680
# Epoch 373/500, Train Acc: 0.9001, Val Acc: 0.8684
# Epoch 374/500, Train Acc: 0.9002, Val Acc: 0.8674
# Epoch 375/500, Train Acc: 0.9003, Val Acc: 0.8680
# Epoch 376/500, Train Acc: 0.9003, Val Acc: 0.8687
# Epoch 377/500, Train Acc: 0.9003, Val Acc: 0.8680
# Epoch 378/500, Train Acc: 0.9003, Val Acc: 0.8690
# Epoch 379/500, Train Acc: 0.9007, Val Acc: 0.8691
# Epoch 380/500, Train Acc: 0.9005, Val Acc: 0.8686
# Epoch 381/500, Train Acc: 0.9007, Val Acc: 0.8686
# Epoch 382/500, Train Acc: 0.9006, Val Acc: 0.8689
# Epoch 383/500, Train Acc: 0.9009, Val Acc: 0.8690
# Epoch 384/500, Train Acc: 0.9006, Val Acc: 0.8686
# Epoch 385/500, Train Acc: 0.9007, Val Acc: 0.8693
# Epoch 386/500, Train Acc: 0.9005, Val Acc: 0.8693
# Epoch 387/500, Train Acc: 0.9004, Val Acc: 0.8694
# Epoch 388/500, Train Acc: 0.9005, Val Acc: 0.8694
# Epoch 389/500, Train Acc: 0.9009, Val Acc: 0.8689
# Epoch 390/500, Train Acc: 0.9007, Val Acc: 0.8691
# Epoch 391/500, Train Acc: 0.9009, Val Acc: 0.8690
# Epoch 392/500, Train Acc: 0.9006, Val Acc: 0.8694
# Epoch 393/500, Train Acc: 0.9006, Val Acc: 0.8691
# Epoch 394/500, Train Acc: 0.9012, Val Acc: 0.8694
# Epoch 395/500, Train Acc: 0.9009, Val Acc: 0.8694
# Epoch 396/500, Train Acc: 0.9006, Val Acc: 0.8693
# Epoch 397/500, Train Acc: 0.9011, Val Acc: 0.8694
# Epoch 398/500, Train Acc: 0.9009, Val Acc: 0.8699
# Epoch 399/500, Train Acc: 0.9011, Val Acc: 0.8700
# Epoch 400/500, Train Acc: 0.9008, Val Acc: 0.8696
# Epoch 401/500, Train Acc: 0.9007, Val Acc: 0.8696
# Epoch 402/500, Train Acc: 0.9008, Val Acc: 0.8699
# Epoch 403/500, Train Acc: 0.9011, Val Acc: 0.8686
# Epoch 404/500, Train Acc: 0.9008, Val Acc: 0.8701
# Epoch 405/500, Train Acc: 0.9009, Val Acc: 0.8693
# Epoch 406/500, Train Acc: 0.9007, Val Acc: 0.8690
# Epoch 407/500, Train Acc: 0.9009, Val Acc: 0.8694
# Epoch 408/500, Train Acc: 0.9008, Val Acc: 0.8699
# Epoch 409/500, Train Acc: 0.9011, Val Acc: 0.8693
# Epoch 410/500, Train Acc: 0.9010, Val Acc: 0.8694
# Epoch 411/500, Train Acc: 0.9007, Val Acc: 0.8697
# Epoch 412/500, Train Acc: 0.9008, Val Acc: 0.8687
# Epoch 413/500, Train Acc: 0.9008, Val Acc: 0.8693
# Epoch 414/500, Train Acc: 0.9009, Val Acc: 0.8693
# Epoch 415/500, Train Acc: 0.9009, Val Acc: 0.8694
# Epoch 416/500, Train Acc: 0.9008, Val Acc: 0.8691
# Epoch 417/500, Train Acc: 0.9011, Val Acc: 0.8690
# Epoch 418/500, Train Acc: 0.9007, Val Acc: 0.8690
# Epoch 419/500, Train Acc: 0.9011, Val Acc: 0.8693
# Epoch 420/500, Train Acc: 0.9011, Val Acc: 0.8690
# Epoch 421/500, Train Acc: 0.9006, Val Acc: 0.8690
# Epoch 422/500, Train Acc: 0.9010, Val Acc: 0.8683
# Epoch 423/500, Train Acc: 0.9012, Val Acc: 0.8689
# Epoch 424/500, Train Acc: 0.9008, Val Acc: 0.8689
# Epoch 425/500, Train Acc: 0.9012, Val Acc: 0.8687
# Epoch 426/500, Train Acc: 0.9010, Val Acc: 0.8689
# Epoch 427/500, Train Acc: 0.9009, Val Acc: 0.8693
# Epoch 428/500, Train Acc: 0.9011, Val Acc: 0.8687
# Epoch 429/500, Train Acc: 0.9010, Val Acc: 0.8690
# Epoch 430/500, Train Acc: 0.9013, Val Acc: 0.8686
# Epoch 431/500, Train Acc: 0.9008, Val Acc: 0.8686
# Epoch 432/500, Train Acc: 0.9012, Val Acc: 0.8694
# Epoch 433/500, Train Acc: 0.9012, Val Acc: 0.8681
# Epoch 434/500, Train Acc: 0.9011, Val Acc: 0.8683
# Epoch 435/500, Train Acc: 0.9014, Val Acc: 0.8684
# Epoch 436/500, Train Acc: 0.9011, Val Acc: 0.8681
# Epoch 437/500, Train Acc: 0.9011, Val Acc: 0.8676
# Epoch 438/500, Train Acc: 0.9011, Val Acc: 0.8683
# Epoch 439/500, Train Acc: 0.9011, Val Acc: 0.8680
# Epoch 440/500, Train Acc: 0.9011, Val Acc: 0.8683
# Epoch 441/500, Train Acc: 0.9010, Val Acc: 0.8683
# Epoch 442/500, Train Acc: 0.9012, Val Acc: 0.8683
# Epoch 443/500, Train Acc: 0.9009, Val Acc: 0.8679
# Epoch 444/500, Train Acc: 0.9015, Val Acc: 0.8677
# Epoch 445/500, Train Acc: 0.9016, Val Acc: 0.8674
# Epoch 446/500, Train Acc: 0.9010, Val Acc: 0.8686
# Epoch 447/500, Train Acc: 0.9012, Val Acc: 0.8681
# Epoch 448/500, Train Acc: 0.9015, Val Acc: 0.8673
# Epoch 449/500, Train Acc: 0.9014, Val Acc: 0.8679
# Epoch 450/500, Train Acc: 0.9016, Val Acc: 0.8683
# Epoch 451/500, Train Acc: 0.9013, Val Acc: 0.8684
# Epoch 452/500, Train Acc: 0.9021, Val Acc: 0.8676
# Epoch 453/500, Train Acc: 0.9016, Val Acc: 0.8684
# Epoch 454/500, Train Acc: 0.9016, Val Acc: 0.8679
# Epoch 455/500, Train Acc: 0.9016, Val Acc: 0.8679
# Epoch 456/500, Train Acc: 0.9017, Val Acc: 0.8687
# Epoch 457/500, Train Acc: 0.9018, Val Acc: 0.8671
# Epoch 458/500, Train Acc: 0.9013, Val Acc: 0.8683
# Epoch 459/500, Train Acc: 0.9016, Val Acc: 0.8681
# Epoch 460/500, Train Acc: 0.9018, Val Acc: 0.8681
# Epoch 461/500, Train Acc: 0.9014, Val Acc: 0.8683
# Epoch 462/500, Train Acc: 0.9014, Val Acc: 0.8679
# Epoch 463/500, Train Acc: 0.9016, Val Acc: 0.8677
# Epoch 464/500, Train Acc: 0.9015, Val Acc: 0.8691
# Epoch 465/500, Train Acc: 0.9014, Val Acc: 0.8684
# Epoch 466/500, Train Acc: 0.9016, Val Acc: 0.8681
# Epoch 467/500, Train Acc: 0.9017, Val Acc: 0.8671
# Epoch 468/500, Train Acc: 0.9013, Val Acc: 0.8677
# Epoch 469/500, Train Acc: 0.9013, Val Acc: 0.8677
# Epoch 470/500, Train Acc: 0.9013, Val Acc: 0.8677
# Epoch 471/500, Train Acc: 0.9016, Val Acc: 0.8681
# Epoch 472/500, Train Acc: 0.9014, Val Acc: 0.8676
# Epoch 473/500, Train Acc: 0.9016, Val Acc: 0.8671
# Epoch 474/500, Train Acc: 0.9013, Val Acc: 0.8667
# Epoch 475/500, Train Acc: 0.9017, Val Acc: 0.8680
# Epoch 476/500, Train Acc: 0.9012, Val Acc: 0.8686
# Epoch 477/500, Train Acc: 0.9012, Val Acc: 0.8681
# Epoch 478/500, Train Acc: 0.9013, Val Acc: 0.8680
# Epoch 479/500, Train Acc: 0.9016, Val Acc: 0.8684
# Epoch 480/500, Train Acc: 0.9016, Val Acc: 0.8680
# Epoch 481/500, Train Acc: 0.9018, Val Acc: 0.8681
# Epoch 482/500, Train Acc: 0.9013, Val Acc: 0.8677
# Epoch 483/500, Train Acc: 0.9020, Val Acc: 0.8676
# Epoch 484/500, Train Acc: 0.9016, Val Acc: 0.8674
# Epoch 485/500, Train Acc: 0.9015, Val Acc: 0.8681
# Epoch 486/500, Train Acc: 0.9015, Val Acc: 0.8676
# Epoch 487/500, Train Acc: 0.9018, Val Acc: 0.8666
# Epoch 488/500, Train Acc: 0.9015, Val Acc: 0.8666
# Epoch 489/500, Train Acc: 0.9017, Val Acc: 0.8663
# Epoch 490/500, Train Acc: 0.9020, Val Acc: 0.8664
# Epoch 491/500, Train Acc: 0.9018, Val Acc: 0.8657
# Epoch 492/500, Train Acc: 0.9019, Val Acc: 0.8664
# Epoch 493/500, Train Acc: 0.9019, Val Acc: 0.8666
# Epoch 494/500, Train Acc: 0.9017, Val Acc: 0.8663
# Epoch 495/500, Train Acc: 0.9018, Val Acc: 0.8670
# Epoch 496/500, Train Acc: 0.9020, Val Acc: 0.8663
# Epoch 497/500, Train Acc: 0.9021, Val Acc: 0.8667
# Epoch 498/500, Train Acc: 0.9020, Val Acc: 0.8664
# Epoch 499/500, Train Acc: 0.9018, Val Acc: 0.8670
# Epoch 500/500, Train Acc: 0.9021, Val Acc: 0.8667

# %%
# انتخاب بهترین وزن‌ها بر اساس بالاترین دقت اعتبارسنجی
best_epoch = np.argmax(weights_history_mlp["val_acc"])
w_mlp1 = weights_history_mlp["w_mlp1"][best_epoch]
b_mlp1 = weights_history_mlp["b_mlp1"][best_epoch]
w_mlp2 = weights_history_mlp["w_mlp2"][best_epoch]
b_mlp2 = weights_history_mlp["b_mlp2"][best_epoch]
print(f"Best weights for MLP selected from epoch {best_epoch + 1} with Val Acc: {weights_history_mlp['val_acc'][best_epoch]:.4f}")
# Out:
# Best weights for MLP selected from epoch 97 with Val Acc: 0.8717

# %% [markdown]
# ## Result

# %%
y_pred = []
for i in range(num_test):
    bottleneck = full_feedforward_encoder(X_test_noisy[i])
    net_mlp1 = np.dot(w_mlp1, bottleneck) + b_mlp1
    out_mlp1 = get_activation(net_mlp1, HP.ACT_MLP1)
    net_mlp2 = np.dot(w_mlp2, out_mlp1) + b_mlp2
    out_mlp2 = get_activation(net_mlp2, HP.ACT_MLP2)
    y_pred.append(np.argmax(out_mlp2))
cm = confusion_matrix(y_test_labels, y_pred)

plt.figure(figsize=(20, 15))

# %%
plt.figure(figsize=(10, 6))
for i in range(1, 4):
    plt.plot(train_mse_history[f"Pair_{i}"], label=f"Train Pair {i}", linewidth=2)
    plt.plot(val_mse_history[f"Pair_{i}"], label=f"Val Pair {i}", linestyle='--', linewidth=2)
plt.title("Autoencoder Training and Validation Loss", fontsize=14, pad=10)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("MSE", fontsize=12)
plt.legend(fontsize=10, loc="upper right")
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_acc_history, label="Train Accuracy", linewidth=2, color='blue')
plt.plot(val_acc_history, label="Validation Accuracy", linestyle='--', linewidth=2, color='orange')
plt.title("MLP Classification Accuracy", fontsize=14, pad=10)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.legend(fontsize=10, loc="lower right")
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False, annot_kws={"size": 12})
plt.title("Confusion Matrix", fontsize=14, pad=10)
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("True", fontsize=12)
plt.tight_layout()
plt.show()

# %%
num_samples_to_show = 15
plt.figure(figsize=(15, 5))  # تنظیم اندازه برای نمایش 5 نمونه در یک ردیف

for i in range(num_samples_to_show):
    # Noisy Input
    plt.subplot(3, num_samples_to_show, i + 1)
    plt.imshow(X_test_noisy[i].reshape(28, 28), cmap="gray")
    if i == 0:
        plt.title("Noisy Input", fontsize=12, pad=10)
    plt.axis("off")
    
    # Denoised Output
    bottleneck = full_feedforward_encoder(X_test_noisy[i])  # خروجی bottleneck برای هر نمونه
    net_dec3 = np.dot(w_dec3, bottleneck) + b_dec3
    out_dec3 = get_activation(net_dec3, HP.ACT_DEC3)  # خروجی دیکودر سوم
    plt.subplot(3, num_samples_to_show, i + 1 + num_samples_to_show)
    plt.imshow(out_dec3.reshape(28, 28), cmap="gray")
    if i == 0:
        plt.title("Denoised Output", fontsize=12, pad=10)
    plt.axis("off")
    
    # Original Image
    plt.subplot(3, num_samples_to_show, i + 1 + 2 * num_samples_to_show)
    plt.imshow(X_test_clean[i].reshape(28, 28), cmap="gray")
    if i == 0:
        plt.title("Original Image", fontsize=12, pad=10)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save and Load weights

# %%
import pickle
import os

WEIGHTS_FILE = "model_weights.pkl"

def save_weights():
    """ذخیره وزن‌ها و بایاس‌های مدل در یک فایل."""
    weights = {
        # Autoencoder weights
        "w_enc1_upper": w_enc1_upper,
        "b_enc1_upper": b_enc1_upper,
        "w_enc1_lower": w_enc1_lower,
        "b_enc1_lower": b_enc1_lower,
        "w_dec1": w_dec1,
        "b_dec1": b_dec1,
        "w_enc2": w_enc2,
        "b_enc2": b_enc2,
        "w_dec2": w_dec2,
        "b_dec2": b_dec2,
        "w_enc3": w_enc3,
        "b_enc3": b_enc3,
        "w_dec3": w_dec3,
        "b_dec3": b_dec3,
        # MLP weights
        "w_mlp1": w_mlp1,
        "b_mlp1": b_mlp1,
        "w_mlp2": w_mlp2,
        "b_mlp2": b_mlp2
    }
    with open(WEIGHTS_FILE, "wb") as f:
        pickle.dump(weights, f)
    print(f"Weights saved to {WEIGHTS_FILE}")

def load_weights():
    """بارگذاری وزن‌ها و بایاس‌ها از فایل."""
    global w_enc1_upper, b_enc1_upper, w_enc1_lower, b_enc1_lower, w_dec1, b_dec1
    global w_enc2, b_enc2, w_dec2, b_dec2, w_enc3, b_enc3, w_dec3, b_dec3
    global w_mlp1, b_mlp1, w_mlp2, b_mlp2
    
    if os.path.exists(WEIGHTS_FILE):
        with open(WEIGHTS_FILE, "rb") as f:
            weights = pickle.load(f)
        
        # Autoencoder weights
        w_enc1_upper = weights["w_enc1_upper"]
        b_enc1_upper = weights["b_enc1_upper"]
        w_enc1_lower = weights["w_enc1_lower"]
        b_enc1_lower = weights["b_enc1_lower"]
        w_dec1 = weights["w_dec1"]
        b_dec1 = weights["b_dec1"]
        w_enc2 = weights["w_enc2"]
        b_enc2 = weights["b_enc2"]
        w_dec2 = weights["w_dec2"]
        b_dec2 = weights["b_dec2"]
        w_enc3 = weights["w_enc3"]
        b_enc3 = weights["b_enc3"]
        w_dec3 = weights["w_dec3"]
        b_dec3 = weights["b_dec3"]
        # MLP weights
        w_mlp1 = weights["w_mlp1"]
        b_mlp1 = weights["b_mlp1"]
        w_mlp2 = weights["w_mlp2"]
        b_mlp2 = weights["b_mlp2"]
        
        print(f"Weights loaded from {WEIGHTS_FILE}")
    else:
        print(f"Error: {WEIGHTS_FILE} not found. Please train the model first.")

save_weights()

# load_weights()
# Out:
# Weights saved to model_weights.pkl
